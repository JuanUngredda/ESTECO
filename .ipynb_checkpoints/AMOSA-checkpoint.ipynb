# %% [markdown]
# # PACKAGES
#
# The following packages are needed in order to properly implement AMOSA. The "PyGMO" package shown below as "pygmo" is a scientific library providing a large number of optimisation problems and algorithms. This package is used to extract the non-dominated subset from a set of solutions. "SciPy" written below as "scipy", is also used to carry out single linkage clustering within the AMOSA algorithm. The remaining packages that have been implemented are used for general mathematics that is carried out within the code.

# %%
from pygmo import *
import pygmo as pyg
import numpy as np
import pandas as pd
import random as rd
import scipy as sci
import math as mth
from sympy import *
from scipy.special import gammainc
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import linkage
from scipy.spatial import distance

# %% [markdown]
# # ESTECO Code

# %%
#   ****************************************
#   ***   Code written by Jessica Wu     ***
#   ***        lw353@cornell.edu         ***
#   ****************************************

# Translated by Michael Luya from Matlab to Python on 3/4/2018.
# Updated by Juan on 7/4/2018.

# Last updated 8/1/2012

# RETURNS: average total cost of production, transportation, outsourcing,
# and inventory holdings

import numpy as np
import randomstate as rnd
import random as rd

def SupplyChain(x, runlength, seed):
    
    x = np.reshape(x,(5,3)) #Add this line in case of using PYGMO
    
# x is a 5x3 matrix, and it specifies the policy used to determine production
# runlength is the number of years to run the simulation
# seed is the index of the substreams to use (integer >= 1)
# other is not used

    if (np.sum(np.sum(k < 0 for k in x))>0 or (runlength <= 0) or
        (runlength != round(runlength)) or (seed <= 0) or (round(seed) != seed)):
        print('x should be >= 0, runlength should be positive integer, seed must be a positive integer\n')
        
    else:
        T = 52 # number of periods
        var = .3 # coeff of the variation of demand
        facilities = 3 # number of production plants
        salesRegions = 8
        products = 5 # number of products
        C = [.3, .5, .4, .2, .4] # production cost in dollars
        t = .02 # transportation cost 
        h = [.4, .3, .6, .2, .3] # inventory cost
        # e = [.8 .7 1.2 .9 1.1] # outsourcing cost
        e = [0.01, 0.01, 0.01, 0.01, 0.01] # outsourcing cost
        distance = np.array([[32, 21, 19, 31, 22, 35, 18, 33],
                            [25, 36, 30, 24, 16, 14, 31, 19],
                            [18, 12, 27, 11, 33, 28, 23, 22]]) # distance in miles from facility to sales region
        maximum = 70 # maximum order size
        minimum = 1 # minimum order size
        
    ## Generate data ##############################################################################################
    
    ExpectedStream = rnd.prng.mrg32k3a.RandomState(seed)
    DemandStream = ExpectedStream # MODIFIED JUAN
    
    U = np.round(ExpectedStream.normal(6,2,size = [5,8])); # mean demand from each region for each product
    U = U.astype(int)
    
    demands = np.zeros((products, salesRegions, T*runlength))
    
    for i in range(0,T*runlength): 
        
        demands[:,:,i] = np.round(DemandStream.normal(U,np.sqrt(var)))
        
        #The while loop runs until the accumulated demand is between minimun and maximun (JUAN)
        while np.sum(np.sum(k < minimum for k in demands[:,:,i])) or np.sum(np.sum(k > maximum for k in demands[:,:,i])):
            
            demands[:,:,i] = np.round(DemandStream.normal(U,np.sqrt(var)))
            
    ## Main Simulation ############################################################################################
    
    P = np.zeros((products,facilities, T*runlength)) # amount produced
    S = np.zeros((products,facilities, T*runlength)) # amount transported
    O = np.zeros((products,salesRegions, T*runlength)) # amount outsourced
    I = np.zeros((products,facilities, T*runlength+1)) # inventory levels
    serviceLevel = 0
    
    targetInventory = np.zeros((products, facilities))
  
    # COMPUTES THE INVENTORY IN EACH FACILITY TO SUPPLY THE THREE NEAREST SALES REGIONS.
    # IF X=1's the inventory is equal to the demand. COMMENT JUAN
    for i in range(0,facilities):       
        base = 0    
        for j in range(0,3):     
            low = 1000
            index = 0         
            for k in range(0,salesRegions): # finding the three closest sales regions           
                dki = distance[i,k] #COMPUTING DISTANCE BETWEEN FACILITIES AND SALES REGIONS. CHANGED BY JUAN
                if dki < low and dki >base:            
                    low = dki
                    index = k         
            base = low
            targetInventory[:,i] = targetInventory[:,i] + U[:,index] # targetInv at facility i and mean demand at sales region_index
            # total targetInventory from all facilities
#     print('Mean Demand')
#     print(U)
    
    targetInventory = np.multiply(targetInventory, x) #JBR
    #print(targetInventory)
    for i in range(0,T*runlength):
#         print('Inventory lvl:' ,I[:,:,i])
#         print('Demand product x SalesRegion:' ,demands[:,:,i])
#         print('targetInventory: ',targetInventory)
#         print('Amount Produced(P) products x facilities: ',P[:,:,i])
#         print('Amount Transported(S) products x facilities: ',S[:,:,i])
#         print('Amount Outsourced(O) products x salesregions: ',O[:,:,i])
        if (I[:,:,i] < targetInventory).all(): #MODIFIED JUAN. Now produces everytime there's a shortage in any product on inventary
            P[:,:,i] = targetInventory - I[:,:,i] # producing to the target inventory level
            I[:,:,i] = I[:,:,i] + P[:,:,i]  # total amount of target inventory level

        #FINDING CLOSEST FACILITY. SAME STRUCTURE AS BEFORE.COMMENT BY JUAN. 
        for j in range(0,salesRegions):
            base = 0
            for m in range(0,3):   
                low = 1000
                index = 0
                for k in range(0,facilities): # find the closest facilities 
                    dkj = distance[k,j] # CHANGED BY JUAN
                    if dkj < low and dkj > base:  
                        low = dkj
                        index = k
                    
                for k in range(0,products): # facility fills the orders
                    
                    if demands[k,j,i] > I[k,index,i] and demands[k,j,i] > 0:
                        
                        demands[k,j,i] = demands[k,j,i] - I[k,index,i]  # total demand - inv.levels
                        S[k,index,i] = I[k,index,i]  # amount transported = inventory levels
                        I[k,index,i] = 0
                        I[k,index,i+1] = I[k,index,i] #MODIFIED JUAN
                        
                    elif demands[k,j,i] <= I[k,index,i] and demands[k,j,i] > 0:
                        
                        S[k,index,i] = demands[k,j,i] # transport all the demands
                        demands[k,j,i] = 0  # zero demands left
                        I[k,index,i] = I[k,index,i] - S[k,index,i]  # inv.level at facility..- amount transported
                        #if i < T*runlength-1:   # otherwise i+1 is bigger than the size T*runlength #MODIFIED JUAN
                        I[k,index,i+1] = I[k,index,i]
                                        
                    base = low # to find the next closest facility


            for k in range(0,products):
                
                if demands[k,j,i] > 0: # remaining order is filled by outsourcing
                    
                    O[k,j,i] = demands[k,j,i]
                    demands[k,j,i] = 0
                    serviceLevel += 1        

# Single objective 
    costs = np.sum(C*np.sum(np.sum(P,axis = 2),axis = 1)) + np.sum(t*np.sum(np.sum(S,axis = 2),axis = 1)) + np.sum(e*np.sum(np.sum(O,axis = 2),axis = 1))+ np.sum(h*np.sum(np.sum(I,axis = 2),axis = 1))
                
    
    ## End of Simulation; Generate results ######################################################################
    
    fn =  costs/runlength/np.sum(np.sum(np.sum(P,axis = 2),axis = 1)) # cost function
    fn2 = np.float((products*salesRegions*runlength*T - serviceLevel))/np.float(products*salesRegions*T*runlength) #customer service level

    return [fn, -fn2] #change the sign of fn2 in case of minimize both problems.
# Out:
# /usr/local/lib/python3.6/dist-packages/randomstate/__init__.py:66: RandomStateDeprecationWarning:
# **End-of-life notification**
#
# This library was designed to bring alternative generators to the NumPy
# infrastructure. It as been successful in advancing the conversation
# for a future implementation of a new random number API in NumPy which
# will allow new algorithms and/or generators. The next step
# in this process is to separate the basic (or core RNG) from the
# functions that transform random bits into useful random numbers.
# This has been implemented in a successor project  **randomgen**
# available on GitHub
#
# https://github.com/bashtage/randomgen
#
# or PyPi
#
# https://pypi.org/project/randomstate/.
#
# randomgen has a slightly different API, so please see the randomgen documentation
#
# https://bashtage.github.io/randomgen.
#
#   warnings.warn(DEPRECATION_MESSAGE, RandomStateDeprecationWarning)

# %% [markdown]
# # AMOSA Code

# %% [markdown]
# The following pieces of code are implemented in AMOSA and AMOSA with RTEA.

# %%
def paramtup(A):
    
    # Turns a vector into a tuple.
    
    B = ()    
    for i in range(0,len(A)):
        B += (A[i],)  
    return B

def tupvec(A):
    
    # Turns a tuple into a vector.
    
    x = (np.asarray(A)).tolist()
    return x

def ineqrandn2(param):
    
    # Generates a random set of coordinates where param is a set of symbolic vairables.
    
    pt = [rd.uniform(0.6,1.1) for i in range(len(param))]   
    
    if np.count_nonzero(pt) != len(param) :
        return ineqrandn2(param) 
    
    else:
        return pt
    
def dominance(currf, newf, evalptlist):
    
    # Returns a vector expressing the dominance of one point over another. If the kth entry in the vector is
    # negative, then currf has a higher value than newf in that entry. If the kth entry is positive, then
    # currf has a lower value than newf in that entry.
    
    Xpts = [evalptlist[i][0] for i in range(len(evalptlist))]    
    R = np.absolute([max(Xpts) - min(Xpts), 1])    
    V = [(currf[i] - newf[i])/R[i] for i in range(len(currf))]
        
    return V 

def avSupplyChain(pt, runlength, k) :
    
    # This function takes a given decision vector called pt and calculates the value of the SupplyChain code using 
    # that decision vector with different random seeds. This is achieved using a given runlength. Once k of these
    # evaluations are made, the mean of the evaluations is returned.
    
    return np.mean([SupplyChain(pt, runlength, i) for i in k], axis = 0).tolist()

def singlecluster(INDICES, v, k):
    
    # Carries out single linkage clustering and returns a list of the indices of k points which represent
    # the clusters you are seeking. This algorithm runs recursively, starting with a list of points v with
    # corresponding indices named INDICES.
    
    n = len(INDICES)
    
    if n <= k:
        
        vnew = [v[i] for i in INDICES]
        return INDICES
    
    else:
        vnew = [v[i] for i in INDICES]
        Z = linkage(vnew, 'single')
        
        i1 = np.int(Z[0][0])
        i2 = np.int(Z[0][1])
        pt1 = v[i1]
        pt2 = v[i2]
        
        w = []
        
        for i in INDICES:
            
            if i != i1 or i!= i2:
                w.append(v[i])
                
        meanD1 = np.mean(distance.cdist([pt1], w, 'euclidean'))
        meanD2 = np.mean(distance.cdist([pt2], w, 'euclidean'))
        means = [meanD1,meanD2]
        
        j = np.min(means)
        
        if j == meanD1:
            INDICES.pop(i2)
        elif j == meanD2:
            INDICES.pop(i1)
            
        return singlecluster(INDICES, v, k)

# %% [markdown]
# The following code is used to carry out the AMOSA algorithm, which has been  presented in the following paper:
#
# https://ieeexplore.ieee.org/document/4358775/.
#
# This algorithm is performed perfectly except for the implementation of Metropolis acceptance probabilities in oppose to sigmoidal ones.

# %%
def AMOSAminESTECO(xmins,xmaxs,param,ineqs,HL,SL,runlength,iterations,T_min,budget):
    
    # This function is used to construct an archive of points from which we can estimate the pareto optimal front
    # of the problem. This algorithm taken from the AMOSA.pdf supplied on the Dropbox.
    
    # xmins = A list of the minimum values which each entry of the stock vector can take.
    # xmaxs = A list of the minimum values which each entry of the stock vector can take.
    # param = Symbolic parameters representing each entry in the stock vector.
    # ineqs = Inequalities defined symbolically expressing the feasible region of the problem.
    # HL = The maximum number of points that the algorithm returns.
    # SL = The maximum number of points the algorithm deals with at any one time.
    # runlength = Same as the runlength parameter in the SupplyChain function.
    # iterations = The initial number of times the dominance of points are compared in the first computational
    # temperature.
    # T_min = Once the computational temperature becomes lower than this, the algorithm will cluster the 
    # archive down to HL points.
    # budget = The total budget size.
    
    m = len(param)
            
    if len(xmins) != len(xmaxs) or len(xmins) != m or len(xmaxs) != m:
        print('The number of parameters and the numbers of their respective minimum and maximum bounds do not match.')
        return
    
    elif HL > SL:
        print('HL must be an integer less than or equal to SL.')
            
    else:
                
        T = 1 # Initializing temperature.
        alpha = 0.9 # Factor used to reduce the temperature. Lower this to a minimum of 0.86 if algorithm is too slow.
        beta = 1.005 # Factor used to increase iteration length per temperature.
        ref_point = [1,-0.1] # The reference point used for hypervolume calculations.
        t_eval = 0 # t_eval tells us how much of the budget has been used.
        
        # Initialize an Archive of points randomly. Evaluations is the list of respective SupplyChain evaluations at
        # these points.
        
######### Initialization. ###########################################################################################
        
        gamma = 2 # Most trivial choice of gamma. Must be an integer greater than 1.
        
        # Creating the Archive.
        
        Archive = [ineqrandn2(param) for i in range(gamma*SL)] # Initial list of decision/stock vectors.
        Evaluations = [] # A vector to be filled with single evaluations of those stock vectors.
        avEvaluations = [] # A vector to be filled with averaged evaluations of those stock vectors. This is used
        # to analyse the performance of the algorithm and is not used to find better solutions.
        Hypervolume = [] # A vector to be filled with hypervolume measures during each stage of the algorithm.
        
        for i in range(len(Archive) - 1):
            t_eval += 1 # One of the budget will be used every time the SupplyChain code is used. 
            print('Archive point %d generated out of %d.'%(t_eval, gamma*HL))
            Evaluations.append(SupplyChain(Archive[i],runlength,1))
            #v = [rd.randint(1,1000) for i in range(10)]
            #avEvaluations.append(avSupplyChain(Archive[i], runlength, v)) # This does not use the budget.
            #hv = hypervolume(avEvaluations)
            #Hypervolume.append(hv.compute(ref_point))
            
        t_eval += 1
        Evaluations.append(SupplyChain(Archive[i],runlength,1))
        #v = [rd.randint(1,1000) for i in range(10)]
        #avEvaluations.append(avSupplyChain(Archive[i], runlength, v))
        print('Archive point %d generated out of %d.'%(t_eval, SL))
        
        # Make this into a non-dominating set of solutions.
        
        paretind = pyg.non_dominated_front_2d(Evaluations)
        Archive = [Archive[i] for i in paretind]
        Evaluations = [Evaluations[i] for i in paretind]
        #avEvaluations = [avEvaluations[i] for i in paretind]
        
        # Cluster if Archive is too big, use single linkage clustering to cut it down to size HL.
        
        if len(Archive) > HL:
            
            v = [q for q in range(len(Archive))]
            newindices = singlecluster(v, Evaluations, HL)
            Archive = [Archive[s] for s in newindices]
            Evaluations = [Evaluations[s] for s in newindices]
            #avEvaluations = [avEvaluations[s] for s in newindices]
        
        #hv = hypervolume(avEvaluations)
        #Hypervolume.append(hv.compute(ref_point))
        
        # Chose a random point from the Archive.
        
        currpt = rd.choice(Archive)
        curreval = Evaluations[Archive.index(currpt)]
        #v = [rd.randint(1,1000) for i in range(10)]
        #avcurreval = avSupplyChain(currpt,runlength,v)
        
        # This was used to check how close we are to finishing the run of the algorithm.
        
        roundnum, numrounds = 0, int(mth.floor((np.log(T_min) - log(T))/log(alpha))) + 1
        
        # Budget size = iterations * numrounds
        
        I = 0
        
        # Choose a random point not necessarily from the Archive.
            
        newpt = ineqrandn2(param)
        t_eval += 1
        #hv = hypervolume(avEvaluations)
        #Hypervolume.append(hv.compute(ref_point))
        
        #v = [rd.randint(1,1000) for i in range(10)]
        neweval = SupplyChain(newpt,runlength, rd.randint(1,1000))
        #avneweval = avSupplyChain(newpt,runlength,v)
        print('t_eval',t_eval)
        
        while T > T_min and t_eval < budget:
            
            print('Temperaure Round %d out of %d.'%(roundnum + 1, numrounds))
            
            roundnum += 1      
            i = 1
            
            if roundnum == numrounds or t_eval + iterations > budget:
                
                iterations = budget - t_eval
            
            while i <= iterations and t_eval < budget:
                    
                print('Iteration %d out of %d.'%(i,mth.floor(iterations)))
                
                i += 1
                I += 1
                dom = dominance(curreval,neweval,Evaluations)
                D = np.sum(1 for number in dom if number < 0)
                
################ CASE 1 ############################################################################################
                
                # If newpt is dominated by currpt.
        
                if D == len(dom):
                
                    # Deriving an acceptance probability.
                    
                    vec = [np.product(np.absolute(dominance(Evaluations[j],neweval,Evaluations))) for 
                                j in range(len(Archive)) if Archive[j] != currpt]
                    S = np.sum(vec)
                    k = len(vec)
                    
                    d = np.product(np.absolute(dom))
                    Dav = (S + d)/(k + 1)
                    p = np.exp(-Dav/T)
                    
                    if rd.random() < p: # If we beat the acceptance probability.
                        
                        currpt, curreval = newpt, neweval
                        #avcurreval = avneweval
                        
                    # A new value for newpt is then generated for the next iteration.
                    
                    newpt = ineqrandn2(param)
                    neweval = SupplyChain(newpt, runlength, rd.randint(1,1000))
                    #v = [rd.randint(1,1000) for i in range(10)]
                    #avneweval = avSupplyChain(newpt, runlength, v)
                    t_eval += 1
                    
                    #hv = hypervolume(avEvaluations)
                    #Hypervolume.append(hv.compute(ref_point))
                    
                    if t_eval >= budget :
                        break
                        
################# CASE 2 ###########################################################################################
                    
                # If neither newpt of currpt dominate each other.
               
                elif D > 0 and D < len(dom):
                    
                    a = len(Archive) 
                    Cplus = [np.sum(1 for number in dominance(neweval,Evaluations[j],Evaluations) 
                                    if number > 0) for j in range(a)]
                    Cminus = [np.sum(1 for number in dominance(neweval,Evaluations[j],Evaluations) 
                                     if number < 0) for j in range(a)]
                    
                    # The list of points in the Archive (not including currpt) that when evaluated dominate the
                    # new point when evaluated.
                    dominating = [Archive[j] for j in range(a) if Cminus[j] == 2 and Archive[j] != currpt]
                    
                    # The list of points in the Archive (not including currpt) that are dominated by
                    # the evaluation of the new point when evaluated.
                    dominated = [Archive[j] for j in range(a) if Cplus[j] == 2 and Archive[j] != currpt]
                    
                    # Evaluations of all the points in dominated.
                    dominatedeval = [Evaluations[j] for j in range(a) if Cplus[j] == 2 and Archive[j] != currpt]
                                
                    k = len(dominating)
                    l = len(dominated)
                    
                    if k > 0: # CASE 2(a)
                        
                        # Deriving the acceptance probability.
                        
                        S = np.sum([np.product(np.absolute(dominance(neweval,Evaluations[j],Evaluations))) 
                                for j in range(a) if Cplus[j] == 2 and Archive[j] != currpt])     
                        Dav = S/k
                        p = np.exp(-Dav/T)
                    
                        if rd.random() < p:
                            
                            Archive.append(newpt)
                            Evaluations.append(neweval)
                            #avEvaluations.append(avneweval)
                            currpt = newpt
                            curreval = neweval
                            #avcurreval = avneweval
                                      
                    elif k == 0 and l == 0: # Case 2(b)
                        
                        # If the newpt dominates no points in the Archive and newpt is not dominated by any points
                        # in the Archive.
                            
                        currpt, curreval = newpt, neweval
                        #avcurreval = avneweval
                        Archive.append(newpt)
                        Evaluations.append(neweval)
                        #avEvaluations.append(avneweval)
                        
                        # Clustering if you have more than SL points. This reduces the number of points
                        # down to HL.
                                           
                        if len(Archive) > SL:
                            
                            v = [q for q in range(len(Archive))]
                            newindices = singlecluster(v, Evaluations, HL)
                            Archive = [Archive[s] for s in newindices]
                            Evaluations = [Evaluations[s] for s in newindices]
                            #avEvaluations = [avEvaluations[s] for s in newindices]
                                    
                        if currpt not in Archive:
                            
                            #v = [q for q in range(len(Archive))]
                            newindices = singlecluster(v, Evaluations, len(Archive) - 1)
                            Archive = [Archive[s] for s in newindices]
                            Evaluations = [Evaluations[s] for s in newindices]
                            #avEvaluations = [avEvaluations[s] for s in newindices]
                                
                            Archive.append(currpt)
                            Evaluations.append(curreval)
                            #avEvaluations.append(avcurreval)
                                                                                      
                    elif l > 0: # Case 2(c)
                            
                        currpt, curreval = newpt, neweval
                        #avcurreval = avneweval
                        Archive.append(newpt)
                        Evaluations.append(neweval)
                        #avEvaluations.append(avneweval)
                        
                        # Removing all of the points that are now dominated by newpt.
                        
                        a = len(Archive)
                        Cminus = [np.sum(1 for number in dominance(neweval,Evaluations[j],Evaluations) 
                                     if number < 0) for j in range(a)]
                        dominated = [Archive[j] for j in range(a) if Cminus[j] == 2 and Archive[j] != currpt]
                        dominatedeval = [Evaluations[j] for j in range(a) if Cminus[j] == 2 and Archive[j] != currpt]
                        
                        nondom = []
                        nondomeval = []
                        #avnondomeval = []
                        
                        for pt in Archive:
                            if pt not in dominated:
                                nondom.append(pt)
                                nondomeval.append(Evaluations[Archive.index(pt)])
                                #avnondomeval.append(avEvaluations[Archive.index(pt)])
                                
                        Archive = nondom
                        Evaluations = nondomeval
                        #avEvaluations = avnondomeval
                    
                    newpt = ineqrandn2(param)
                    neweval = SupplyChain(newpt, runlength, rd.randint(1,1000))
                    #v = [rd.randint(1,1000) for i in range(10)]
                    #avneweval = avSupplyChain(newpt, runlength, v)
                    t_eval += 1
                    
                    #hv = hypervolume(avEvaluations)
                    #Hypervolume.append(hv.compute(ref_point))
                    
                    if t_eval >= budget:
                        break 
                        
################# CASE 3 ###########################################################################################
                                  
                # If newpt dominates currpt.
        
                elif D == 0:
                
                    a = len(Archive) 
                    
                    Cplus = [np.sum(1 for number in dominance(neweval,Evaluations[j],Evaluations) 
                                    if number > 0) for j in range(a)]
                    Cminus = [np.sum(1 for number in dominance(neweval,Evaluations[j],Evaluations) 
                                     if number < 0) for j in range(a)]
                    
                    # For all the points in the Archive that dominate the newpt, dominatingDs is a list
                    # of vectors presenting the amount by which these points are dominating newpt.
                    dominatingDs = [np.product(np.absolute(dominance(Evaluations[j],neweval,Evaluations))) 
                                    for j in range(a) if Cplus[j] == 2 and Archive[j] != currpt]
                    
                    # The indices of the points in Archive that dominate newpt.
                    dominatingindices = [j for j in range(a) if Cplus[j] == 2 and Archive[j] != currpt]
                    
                    # The points in Archive which are dominated by newpt.
                    dominated = [Archive[j] for j in range(a) if Cminus[j] == 2 and Archive[j] != currpt]
                    
                    # The evaluations of all the points in dominated.
                    dominatedeval = [Evaluations[j] for j in range(a) if Cminus[j] == 2 and Archive[j] != currpt]
                    
                    k = len(dominatingindices)
                    l = len(dominated)
                    
                    if k > 0: # CASE 3(a)
                        
                        # If newpt dominates k other points in the Archive.
                            
                        Dmin = np.min(dominatingDs)
                        idx = dominatingindices[dominatingDs.index(Dmin)]
                        
                        minargpt = Archive[idx]
                        minargeval = Evaluations[idx]
                        #avminargeval = avEvaluations[idx]
                        
                        # Acceptance probability.
                        
                        p = np.exp(-Dmin)
                    
                        if rd.random() < p:
                            currpt = minargpt
                            curreval = minargeval
                            #avcurreval = avminargeval
                        
                        else:
                            currpt = newpt
                            curreval = neweval
                            #avcurreval = avneweval
                            
                    elif k == 0 and l == 0: # Case 3(b)
                        
                        # If there are no points in the Archive that dominate newpt and newpt dominates no points.
                        # other than currpt.
                        
                        if currpt in Archive:
                            
                            # Get rid of currpt from our Archive.
                            Evaluations.pop(Archive.index(currpt))
                            #avEvaluations.pop(Archive.index(currpt))
                            Archive.pop(Archive.index(currpt))
                            
                            # Let currpt = newpt and append it to Archive.
                            currpt = newpt
                            curreval = neweval
                            #avcurreval = avneweval
                            Archive.append(currpt)
                            Evaluations.append(curreval)
                            #avEvaluations.append(avcurreval)
                            
                            # Clustering our Archive down to HL points if we happen to have more than SL points.
                            
                            if len(Archive) > SL:
                                           
                                v = [q for q in range(len(Archive))]
                                newindices = singlecluster(v, Evaluations, HL)
                                Archive = [Archive[s] for s in newindices]
                                Evaluations = [Evaluations[s] for s in newindices]
                                #avEvaluations = [avEvaluations[s] for s in newindices]
                                    
                            if currpt not in Archive:
                                
                                v = [q for q in range(len(Archive))]
                                newindices = singlecluster(v, Evaluations, len(Archive) - 1)
                                Archive = [Archive[s] for s in newindices]
                                Evaluations = [Evaluations[s] for s in newindices]
                                #avEvaluations = [avEvaluations[s] for s in newindices]
                                
                                Archive.append(currpt)
                                Evaluations.append(curreval)
                                #avEvaluations.append(avcurreval)
                            
                    elif l > 0: # Case 3(c)
                        
                        # If there are l points in the Archive that are dominated by newpt.
                        
                        # Select newpt as your new currpt.
                        currpt = newpt
                        curreval = neweval
                        #avcurreval = avneweval
                        
                        # Add this new point to your Archive.
                        Archive.append(currpt)
                        Evaluations.append(curreval)
                        #avEvaluations.append(avcurreval)
                        
                        # Removing all of the points that are now dominated by newpt.
                        
                        a = len(Archive)
                        
                        nondom = []
                        nondomeval = []
                        #avnondomeval = []
                        
                        for pt in Archive:
                            if pt not in dominated:
                                nondom.append(pt)
                                nondomeval.append(Evaluations[Archive.index(pt)])
                                #avnondomeval.append(avEvaluations[Archive.index(pt)])
                                
                        Archive = nondom
                        Evaluations = nondomeval
                        #avEvaluations = avnondomeval
                        
                    # Generate a new vector for newpt.
                    
                    newpt = ineqrandn2(param)
                    neweval = SupplyChain(newpt, runlength, rd.randint(1,1000))
                    #v = [rd.randint(1,1000) for i in range(10)]
                    #avneweval = avSupplyChain(newpt, runlength, v)
                    t_eval += 1
                    
                    #hv = hypervolume(avEvaluations)
                    #Hypervolume.append(hv.compute(ref_point))
                    
                    if t_eval >= budget:
                        break
                            
            # Reducing the temperature.
            
            T *= alpha
            iterations *= beta
            print('t_eval',t_eval)
                
############# Clustering our Archive down to HL points if we happen to have more than SL points. ###################
        
        if len(Archive) > SL:
            
            v = [q for q in range(len(Archive))]
            newindices = singlecluster(v, Evaluations, HL)
            Archive = [Archive[s] for s in newindices]
            Evaluations = [Evaluations[s] for s in newindices]
            #avEvaluations = [avEvaluations[s] for s in newindices]
            
        # The following code then takes the non-dominated set of solutions which the algorithm then returns.
        
        paretind = pyg.non_dominated_front_2d(Evaluations)
        Archive = [Archive[w] for w in paretind]
        Evaluations = [Evaluations[w] for w in paretind]
        #avEvaluations = [avEvaluations[w] for w in paretind]
        
        #hv = hypervolume(avEvaluations)
        #Hypervolume[-1] = hv.compute(ref_point)
                    
        return [Archive, Evaluations, Hypervolume]

# %% [markdown]
# # Example Run of AMOSA

# %%
# These are the parameters that need to be included in the algorithm above.

X = [[Symbol('x_%d%d'%(i,j)) for j in range(5)] for i in range(3)] #param
Xparam = np.reshape(X,(1,15))[0]
MIN = [0.6 for i in range(15)] #xmins
MAX = [1.1 for i in range(15)] #xmaxs
inequalities = [Xparam[k] > 0 for k in range(15)] #ineqs
H = 40 # HL
S = 40 # SL
iters = 40 # iterations
T_minimum = 0.9**80.5 # T_min
Budget = 4000 # budget

# %%
a = AMOSAminESTECO(MIN,MAX,Xparam,inequalities,40,40,2,40,1*(0.9**79.5),4000)
# Out:
# Archive point 1 generated out of 80.
# Archive point 2 generated out of 80.
# Archive point 3 generated out of 80.
# Archive point 4 generated out of 80.
# Archive point 5 generated out of 80.
# Archive point 6 generated out of 80.
# Archive point 7 generated out of 80.
# Archive point 8 generated out of 80.
# Archive point 9 generated out of 80.
# Archive point 10 generated out of 80.
# Archive point 11 generated out of 80.
# Archive point 12 generated out of 80.
# Archive point 13 generated out of 80.
# Archive point 14 generated out of 80.
# Archive point 15 generated out of 80.
# Archive point 16 generated out of 80.
# Archive point 17 generated out of 80.
# Archive point 18 generated out of 80.
# Archive point 19 generated out of 80.
# Archive point 20 generated out of 80.
# Archive point 21 generated out of 80.
# Archive point 22 generated out of 80.
# Archive point 23 generated out of 80.
# Archive point 24 generated out of 80.
# Archive point 25 generated out of 80.
# Archive point 26 generated out of 80.
# Archive point 27 generated out of 80.
# Archive point 28 generated out of 80.
# Archive point 29 generated out of 80.
# Archive point 30 generated out of 80.
# Archive point 31 generated out of 80.
# Archive point 32 generated out of 80.
# Archive point 33 generated out of 80.
# Archive point 34 generated out of 80.
# Archive point 35 generated out of 80.
# Archive point 36 generated out of 80.
# Archive point 37 generated out of 80.
# Archive point 38 generated out of 80.
# Archive point 39 generated out of 80.
# Archive point 40 generated out of 80.
# Archive point 41 generated out of 80.
# Archive point 42 generated out of 80.
# Archive point 43 generated out of 80.
# Archive point 44 generated out of 80.
# Archive point 45 generated out of 80.
# Archive point 46 generated out of 80.
# Archive point 47 generated out of 80.
# Archive point 48 generated out of 80.
# Archive point 49 generated out of 80.
# Archive point 50 generated out of 80.
# Archive point 51 generated out of 80.
# Archive point 52 generated out of 80.
# Archive point 53 generated out of 80.
# Archive point 54 generated out of 80.
# Archive point 55 generated out of 80.
# Archive point 56 generated out of 80.
# Archive point 57 generated out of 80.
# Archive point 58 generated out of 80.
# Archive point 59 generated out of 80.
# Archive point 60 generated out of 80.
# Archive point 61 generated out of 80.
# Archive point 62 generated out of 80.
# Archive point 63 generated out of 80.
# Archive point 64 generated out of 80.
# Archive point 65 generated out of 80.
# Archive point 66 generated out of 80.
# Archive point 67 generated out of 80.
# Archive point 68 generated out of 80.
# Archive point 69 generated out of 80.
# Archive point 70 generated out of 80.
# Archive point 71 generated out of 80.
# Archive point 72 generated out of 80.
# Archive point 73 generated out of 80.
# Archive point 74 generated out of 80.
# Archive point 75 generated out of 80.
# Archive point 76 generated out of 80.
# Archive point 77 generated out of 80.
# Archive point 78 generated out of 80.
# Archive point 79 generated out of 80.
# Archive point 80 generated out of 40.
# t_eval 81
# Temperaure Round 1 out of 80.
# Iteration 1 out of 40.
# Iteration 2 out of 40.
# Iteration 3 out of 40.
# Iteration 4 out of 40.
# Iteration 5 out of 40.
# Iteration 6 out of 40.
# Iteration 7 out of 40.
# Iteration 8 out of 40.
# Iteration 9 out of 40.
# Iteration 10 out of 40.
# Iteration 11 out of 40.
# Iteration 12 out of 40.
# Iteration 13 out of 40.
# Iteration 14 out of 40.
# Iteration 15 out of 40.
# Iteration 16 out of 40.
# Iteration 17 out of 40.
# Iteration 18 out of 40.
# Iteration 19 out of 40.
# Iteration 20 out of 40.
# Iteration 21 out of 40.
# Iteration 22 out of 40.
# Iteration 23 out of 40.
# Iteration 24 out of 40.
# Iteration 25 out of 40.
# Iteration 26 out of 40.
# Iteration 27 out of 40.
# Iteration 28 out of 40.
# Iteration 29 out of 40.
# Iteration 30 out of 40.
# Iteration 31 out of 40.
# Iteration 32 out of 40.
# Iteration 33 out of 40.
# Iteration 34 out of 40.
# Iteration 35 out of 40.
# Iteration 36 out of 40.
# Iteration 37 out of 40.
# Iteration 38 out of 40.
# Iteration 39 out of 40.
# Iteration 40 out of 40.
# t_eval 121
# Temperaure Round 2 out of 80.
# Iteration 1 out of 40.
# Iteration 2 out of 40.
# Iteration 3 out of 40.
# Iteration 4 out of 40.
# Iteration 5 out of 40.
# Iteration 6 out of 40.
# Iteration 7 out of 40.
# Iteration 8 out of 40.
# Iteration 9 out of 40.
# Iteration 10 out of 40.
# Iteration 11 out of 40.
# Iteration 12 out of 40.
# Iteration 13 out of 40.
# Iteration 14 out of 40.
# Iteration 15 out of 40.
# Iteration 16 out of 40.
# Iteration 17 out of 40.
# Iteration 18 out of 40.
# Iteration 19 out of 40.
# Iteration 20 out of 40.
# Iteration 21 out of 40.
# Iteration 22 out of 40.
# Iteration 23 out of 40.
# Iteration 24 out of 40.
# Iteration 25 out of 40.
# Iteration 26 out of 40.
# Iteration 27 out of 40.
# Iteration 28 out of 40.
# Iteration 29 out of 40.
# Iteration 30 out of 40.
# Iteration 31 out of 40.
# Iteration 32 out of 40.
# Iteration 33 out of 40.
# Iteration 34 out of 40.
# Iteration 35 out of 40.
# Iteration 36 out of 40.
# Iteration 37 out of 40.
# Iteration 38 out of 40.
# Iteration 39 out of 40.
# Iteration 40 out of 40.
# t_eval 161
# Temperaure Round 3 out of 80.
# Iteration 1 out of 40.
# Iteration 2 out of 40.
# Iteration 3 out of 40.
# Iteration 4 out of 40.
# Iteration 5 out of 40.
# Iteration 6 out of 40.
# Iteration 7 out of 40.
# Iteration 8 out of 40.
# Iteration 9 out of 40.
# Iteration 10 out of 40.
# Iteration 11 out of 40.
# Iteration 12 out of 40.
# Iteration 13 out of 40.
# Iteration 14 out of 40.
# Iteration 15 out of 40.
# Iteration 16 out of 40.
# Iteration 17 out of 40.
# Iteration 18 out of 40.
# Iteration 19 out of 40.
# Iteration 20 out of 40.
# Iteration 21 out of 40.
# Iteration 22 out of 40.
# Iteration 23 out of 40.
# Iteration 24 out of 40.
# Iteration 25 out of 40.
# Iteration 26 out of 40.
# Iteration 27 out of 40.
# Iteration 28 out of 40.
# Iteration 29 out of 40.
# Iteration 30 out of 40.
# Iteration 31 out of 40.
# Iteration 32 out of 40.
# Iteration 33 out of 40.
# Iteration 34 out of 40.
# Iteration 35 out of 40.
# Iteration 36 out of 40.
# Iteration 37 out of 40.
# Iteration 38 out of 40.
# Iteration 39 out of 40.
# Iteration 40 out of 40.
# t_eval 201
# Temperaure Round 4 out of 80.
# Iteration 1 out of 40.
# Iteration 2 out of 40.
# Iteration 3 out of 40.
# Iteration 4 out of 40.
# Iteration 5 out of 40.
# Iteration 6 out of 40.
# Iteration 7 out of 40.
# Iteration 8 out of 40.
# Iteration 9 out of 40.
# Iteration 10 out of 40.
# Iteration 11 out of 40.
# Iteration 12 out of 40.
# Iteration 13 out of 40.
# Iteration 14 out of 40.
# Iteration 15 out of 40.
# Iteration 16 out of 40.
# Iteration 17 out of 40.
# Iteration 18 out of 40.
# Iteration 19 out of 40.
# Iteration 20 out of 40.
# Iteration 21 out of 40.
# Iteration 22 out of 40.
# Iteration 23 out of 40.
# Iteration 24 out of 40.
# Iteration 25 out of 40.
# Iteration 26 out of 40.
# Iteration 27 out of 40.
# Iteration 28 out of 40.
# Iteration 29 out of 40.
# Iteration 30 out of 40.
# Iteration 31 out of 40.
# Iteration 32 out of 40.
# Iteration 33 out of 40.
# Iteration 34 out of 40.
# Iteration 35 out of 40.
# Iteration 36 out of 40.
# Iteration 37 out of 40.
# Iteration 38 out of 40.
# Iteration 39 out of 40.
# Iteration 40 out of 40.
# t_eval 241
# Temperaure Round 5 out of 80.
# Iteration 1 out of 40.
# Iteration 2 out of 40.
# Iteration 3 out of 40.
# Iteration 4 out of 40.
# Iteration 5 out of 40.
# Iteration 6 out of 40.
# Iteration 7 out of 40.
# Iteration 8 out of 40.
# Iteration 9 out of 40.
# Iteration 10 out of 40.
# Iteration 11 out of 40.
# Iteration 12 out of 40.
# Iteration 13 out of 40.
# Iteration 14 out of 40.
# Iteration 15 out of 40.
# Iteration 16 out of 40.
# Iteration 17 out of 40.
# Iteration 18 out of 40.
# Iteration 19 out of 40.
# Iteration 20 out of 40.
# Iteration 21 out of 40.
# Iteration 22 out of 40.
# Iteration 23 out of 40.
# Iteration 24 out of 40.
# Iteration 25 out of 40.
# Iteration 26 out of 40.
# Iteration 27 out of 40.
# Iteration 28 out of 40.
# Iteration 29 out of 40.
# Iteration 30 out of 40.
# Iteration 31 out of 40.
# Iteration 32 out of 40.
# Iteration 33 out of 40.
# Iteration 34 out of 40.
# Iteration 35 out of 40.
# Iteration 36 out of 40.
# Iteration 37 out of 40.
# Iteration 38 out of 40.
# Iteration 39 out of 40.
# Iteration 40 out of 40.
# t_eval 281
# Temperaure Round 6 out of 80.
# Iteration 1 out of 41.
# Iteration 2 out of 41.
# Iteration 3 out of 41.
# Iteration 4 out of 41.
# Iteration 5 out of 41.
# Iteration 6 out of 41.
# Iteration 7 out of 41.
# Iteration 8 out of 41.
# Iteration 9 out of 41.
# Iteration 10 out of 41.
# Iteration 11 out of 41.
# Iteration 12 out of 41.
# Iteration 13 out of 41.
# Iteration 14 out of 41.
# Iteration 15 out of 41.
# Iteration 16 out of 41.
# Iteration 17 out of 41.
# Iteration 18 out of 41.
# Iteration 19 out of 41.
# Iteration 20 out of 41.
# Iteration 21 out of 41.
# Iteration 22 out of 41.
# Iteration 23 out of 41.
# Iteration 24 out of 41.
# Iteration 25 out of 41.
# Iteration 26 out of 41.
# Iteration 27 out of 41.
# Iteration 28 out of 41.
# Iteration 29 out of 41.
# Iteration 30 out of 41.
# Iteration 31 out of 41.
# Iteration 32 out of 41.
# Iteration 33 out of 41.
# Iteration 34 out of 41.
# Iteration 35 out of 41.
# Iteration 36 out of 41.
# Iteration 37 out of 41.
# Iteration 38 out of 41.
# Iteration 39 out of 41.
# Iteration 40 out of 41.
# Iteration 41 out of 41.
# t_eval 322
# Temperaure Round 7 out of 80.
# Iteration 1 out of 41.
# Iteration 2 out of 41.
# Iteration 3 out of 41.
# Iteration 4 out of 41.
# Iteration 5 out of 41.
# Iteration 6 out of 41.
# Iteration 7 out of 41.
# Iteration 8 out of 41.
# Iteration 9 out of 41.
# Iteration 10 out of 41.
# Iteration 11 out of 41.
# Iteration 12 out of 41.
# Iteration 13 out of 41.
# Iteration 14 out of 41.
# Iteration 15 out of 41.
# Iteration 16 out of 41.
# Iteration 17 out of 41.
# Iteration 18 out of 41.
# Iteration 19 out of 41.
# Iteration 20 out of 41.
# Iteration 21 out of 41.
# Iteration 22 out of 41.
# Iteration 23 out of 41.
# Iteration 24 out of 41.
# Iteration 25 out of 41.
# Iteration 26 out of 41.
# Iteration 27 out of 41.
# Iteration 28 out of 41.
# Iteration 29 out of 41.
# Iteration 30 out of 41.
# Iteration 31 out of 41.
# Iteration 32 out of 41.
# Iteration 33 out of 41.
# Iteration 34 out of 41.
# Iteration 35 out of 41.
# Iteration 36 out of 41.
# Iteration 37 out of 41.
# Iteration 38 out of 41.
# Iteration 39 out of 41.
# Iteration 40 out of 41.
# Iteration 41 out of 41.
# t_eval 363
# Temperaure Round 8 out of 80.
# Iteration 1 out of 41.
# Iteration 2 out of 41.
# Iteration 3 out of 41.
# Iteration 4 out of 41.
# Iteration 5 out of 41.
# Iteration 6 out of 41.
# Iteration 7 out of 41.
# Iteration 8 out of 41.
# Iteration 9 out of 41.
# Iteration 10 out of 41.
# Iteration 11 out of 41.
# Iteration 12 out of 41.
# Iteration 13 out of 41.
# Iteration 14 out of 41.
# Iteration 15 out of 41.
# Iteration 16 out of 41.
# Iteration 17 out of 41.
# Iteration 18 out of 41.
# Iteration 19 out of 41.
# Iteration 20 out of 41.
# Iteration 21 out of 41.
# Iteration 22 out of 41.
# Iteration 23 out of 41.
# Iteration 24 out of 41.
# Iteration 25 out of 41.
# Iteration 26 out of 41.
# Iteration 27 out of 41.
# Iteration 28 out of 41.
# Iteration 29 out of 41.
# Iteration 30 out of 41.
# Iteration 31 out of 41.
# Iteration 32 out of 41.
# Iteration 33 out of 41.
# Iteration 34 out of 41.
# Iteration 35 out of 41.
# Iteration 36 out of 41.
# Iteration 37 out of 41.
# Iteration 38 out of 41.
# Iteration 39 out of 41.
# Iteration 40 out of 41.
# Iteration 41 out of 41.
# t_eval 404
# Temperaure Round 9 out of 80.
# Iteration 1 out of 41.
# Iteration 2 out of 41.
# Iteration 3 out of 41.
# Iteration 4 out of 41.
# Iteration 5 out of 41.
# Iteration 6 out of 41.
# Iteration 7 out of 41.
# Iteration 8 out of 41.
# Iteration 9 out of 41.
# Iteration 10 out of 41.
# Iteration 11 out of 41.
# Iteration 12 out of 41.
# Iteration 13 out of 41.
# Iteration 14 out of 41.
# Iteration 15 out of 41.
# Iteration 16 out of 41.
# Iteration 17 out of 41.
# Iteration 18 out of 41.
# Iteration 19 out of 41.
# Iteration 20 out of 41.
# Iteration 21 out of 41.
# Iteration 22 out of 41.
# Iteration 23 out of 41.
# Iteration 24 out of 41.
# Iteration 25 out of 41.
# Iteration 26 out of 41.
# Iteration 27 out of 41.
# Iteration 28 out of 41.
# Iteration 29 out of 41.
# Iteration 30 out of 41.
# Iteration 31 out of 41.
# Iteration 32 out of 41.
# Iteration 33 out of 41.
# Iteration 34 out of 41.
# Iteration 35 out of 41.
# Iteration 36 out of 41.
# Iteration 37 out of 41.
# Iteration 38 out of 41.
# Iteration 39 out of 41.
# Iteration 40 out of 41.
# Iteration 41 out of 41.
# t_eval 445
# Temperaure Round 10 out of 80.
# Iteration 1 out of 41.
# Iteration 2 out of 41.
# Iteration 3 out of 41.
# Iteration 4 out of 41.
# Iteration 5 out of 41.
# Iteration 6 out of 41.
# Iteration 7 out of 41.
# Iteration 8 out of 41.
# Iteration 9 out of 41.
# Iteration 10 out of 41.
# Iteration 11 out of 41.
# Iteration 12 out of 41.
# Iteration 13 out of 41.
# Iteration 14 out of 41.
# Iteration 15 out of 41.
# Iteration 16 out of 41.
# Iteration 17 out of 41.
# Iteration 18 out of 41.
# Iteration 19 out of 41.
# Iteration 20 out of 41.
# Iteration 21 out of 41.
# Iteration 22 out of 41.
# Iteration 23 out of 41.
# Iteration 24 out of 41.
# Iteration 25 out of 41.
# Iteration 26 out of 41.
# Iteration 27 out of 41.
# Iteration 28 out of 41.
# Iteration 29 out of 41.
# Iteration 30 out of 41.
# Iteration 31 out of 41.
# Iteration 32 out of 41.
# Iteration 33 out of 41.
# Iteration 34 out of 41.
# Iteration 35 out of 41.
# Iteration 36 out of 41.
# Iteration 37 out of 41.
# Iteration 38 out of 41.
# Iteration 39 out of 41.
# Iteration 40 out of 41.
# Iteration 41 out of 41.
# t_eval 486
# Temperaure Round 11 out of 80.
# Iteration 1 out of 42.
# Iteration 2 out of 42.
# Iteration 3 out of 42.
# Iteration 4 out of 42.
# Iteration 5 out of 42.
# Iteration 6 out of 42.
# Iteration 7 out of 42.
# Iteration 8 out of 42.
# Iteration 9 out of 42.
# Iteration 10 out of 42.
# Iteration 11 out of 42.
# Iteration 12 out of 42.
# Iteration 13 out of 42.
# Iteration 14 out of 42.
# Iteration 15 out of 42.
# Iteration 16 out of 42.
# Iteration 17 out of 42.
# Iteration 18 out of 42.
# Iteration 19 out of 42.
# Iteration 20 out of 42.
# Iteration 21 out of 42.
# Iteration 22 out of 42.
# Iteration 23 out of 42.
# Iteration 24 out of 42.
# Iteration 25 out of 42.
# Iteration 26 out of 42.
# Iteration 27 out of 42.
# Iteration 28 out of 42.
# Iteration 29 out of 42.
# Iteration 30 out of 42.
# Iteration 31 out of 42.
# Iteration 32 out of 42.
# Iteration 33 out of 42.
# Iteration 34 out of 42.
# Iteration 35 out of 42.
# Iteration 36 out of 42.
# Iteration 37 out of 42.
# Iteration 38 out of 42.
# Iteration 39 out of 42.
# Iteration 40 out of 42.
# Iteration 41 out of 42.
# Iteration 42 out of 42.
# t_eval 528
# Temperaure Round 12 out of 80.
# Iteration 1 out of 42.
# Iteration 2 out of 42.
# Iteration 3 out of 42.
# Iteration 4 out of 42.
# Iteration 5 out of 42.
# Iteration 6 out of 42.
# Iteration 7 out of 42.
# Iteration 8 out of 42.
# Iteration 9 out of 42.
# Iteration 10 out of 42.
# Iteration 11 out of 42.
# Iteration 12 out of 42.
# Iteration 13 out of 42.
# Iteration 14 out of 42.
# Iteration 15 out of 42.
# Iteration 16 out of 42.
# Iteration 17 out of 42.
# Iteration 18 out of 42.
# Iteration 19 out of 42.
# Iteration 20 out of 42.
# Iteration 21 out of 42.
# Iteration 22 out of 42.
# Iteration 23 out of 42.
# Iteration 24 out of 42.
# Iteration 25 out of 42.
# Iteration 26 out of 42.
# Iteration 27 out of 42.
# Iteration 28 out of 42.
# Iteration 29 out of 42.
# Iteration 30 out of 42.
# Iteration 31 out of 42.
# Iteration 32 out of 42.
# Iteration 33 out of 42.
# Iteration 34 out of 42.
# Iteration 35 out of 42.
# Iteration 36 out of 42.
# Iteration 37 out of 42.
# Iteration 38 out of 42.
# Iteration 39 out of 42.
# Iteration 40 out of 42.
# Iteration 41 out of 42.
# Iteration 42 out of 42.
# t_eval 570
# Temperaure Round 13 out of 80.
# Iteration 1 out of 42.
# Iteration 2 out of 42.
# Iteration 3 out of 42.
# Iteration 4 out of 42.
# Iteration 5 out of 42.
# Iteration 6 out of 42.
# Iteration 7 out of 42.
# Iteration 8 out of 42.
# Iteration 9 out of 42.
# Iteration 10 out of 42.
# Iteration 11 out of 42.
# Iteration 12 out of 42.
# Iteration 13 out of 42.
# Iteration 14 out of 42.
# Iteration 15 out of 42.
# Iteration 16 out of 42.
# Iteration 17 out of 42.
# Iteration 18 out of 42.
# Iteration 19 out of 42.
# Iteration 20 out of 42.
# Iteration 21 out of 42.
# Iteration 22 out of 42.
# Iteration 23 out of 42.
# Iteration 24 out of 42.
# Iteration 25 out of 42.
# Iteration 26 out of 42.
# Iteration 27 out of 42.
# Iteration 28 out of 42.
# Iteration 29 out of 42.
# Iteration 30 out of 42.
# Iteration 31 out of 42.
# Iteration 32 out of 42.
# Iteration 33 out of 42.
# Iteration 34 out of 42.
# Iteration 35 out of 42.
# Iteration 36 out of 42.
# Iteration 37 out of 42.
# Iteration 38 out of 42.
# Iteration 39 out of 42.
# Iteration 40 out of 42.
# Iteration 41 out of 42.
# Iteration 42 out of 42.
# t_eval 612
# Temperaure Round 14 out of 80.
# Iteration 1 out of 42.
# Iteration 2 out of 42.
# Iteration 3 out of 42.
# Iteration 4 out of 42.
# Iteration 5 out of 42.
# Iteration 6 out of 42.
# Iteration 7 out of 42.
# Iteration 8 out of 42.
# Iteration 9 out of 42.
# Iteration 10 out of 42.
# Iteration 11 out of 42.
# Iteration 12 out of 42.
# Iteration 13 out of 42.
# Iteration 14 out of 42.
# Iteration 15 out of 42.
# Iteration 16 out of 42.
# Iteration 17 out of 42.
# Iteration 18 out of 42.
# Iteration 19 out of 42.
# Iteration 20 out of 42.
# Iteration 21 out of 42.
# Iteration 22 out of 42.
# Iteration 23 out of 42.
# Iteration 24 out of 42.
# Iteration 25 out of 42.
# Iteration 26 out of 42.
# Iteration 27 out of 42.
# Iteration 28 out of 42.
# Iteration 29 out of 42.
# Iteration 30 out of 42.
# Iteration 31 out of 42.
# Iteration 32 out of 42.
# Iteration 33 out of 42.
# Iteration 34 out of 42.
# Iteration 35 out of 42.
# Iteration 36 out of 42.
# Iteration 37 out of 42.
# Iteration 38 out of 42.
# Iteration 39 out of 42.
# Iteration 40 out of 42.
# Iteration 41 out of 42.
# Iteration 42 out of 42.
# t_eval 654
# Temperaure Round 15 out of 80.
# Iteration 1 out of 42.
# Iteration 2 out of 42.
# Iteration 3 out of 42.
# Iteration 4 out of 42.
# Iteration 5 out of 42.
# Iteration 6 out of 42.
# Iteration 7 out of 42.
# Iteration 8 out of 42.
# Iteration 9 out of 42.
# Iteration 10 out of 42.
# Iteration 11 out of 42.
# Iteration 12 out of 42.
# Iteration 13 out of 42.
# Iteration 14 out of 42.
# Iteration 15 out of 42.
# Iteration 16 out of 42.
# Iteration 17 out of 42.
# Iteration 18 out of 42.
# Iteration 19 out of 42.
# Iteration 20 out of 42.
# Iteration 21 out of 42.
# Iteration 22 out of 42.
# Iteration 23 out of 42.
# Iteration 24 out of 42.
# Iteration 25 out of 42.
# Iteration 26 out of 42.
# Iteration 27 out of 42.
# Iteration 28 out of 42.
# Iteration 29 out of 42.
# Iteration 30 out of 42.
# Iteration 31 out of 42.
# Iteration 32 out of 42.
# Iteration 33 out of 42.
# Iteration 34 out of 42.
# Iteration 35 out of 42.
# Iteration 36 out of 42.
# Iteration 37 out of 42.
# Iteration 38 out of 42.
# Iteration 39 out of 42.
# Iteration 40 out of 42.
# Iteration 41 out of 42.
# Iteration 42 out of 42.
# t_eval 696
# Temperaure Round 16 out of 80.
# Iteration 1 out of 43.
# Iteration 2 out of 43.
# Iteration 3 out of 43.
# Iteration 4 out of 43.
# Iteration 5 out of 43.
# Iteration 6 out of 43.
# Iteration 7 out of 43.
# Iteration 8 out of 43.
# Iteration 9 out of 43.
# Iteration 10 out of 43.
# Iteration 11 out of 43.
# Iteration 12 out of 43.
# Iteration 13 out of 43.
# Iteration 14 out of 43.
# Iteration 15 out of 43.
# Iteration 16 out of 43.
# Iteration 17 out of 43.
# Iteration 18 out of 43.
# Iteration 19 out of 43.
# Iteration 20 out of 43.
# Iteration 21 out of 43.
# Iteration 22 out of 43.
# Iteration 23 out of 43.
# Iteration 24 out of 43.
# Iteration 25 out of 43.
# Iteration 26 out of 43.
# Iteration 27 out of 43.
# Iteration 28 out of 43.
# Iteration 29 out of 43.
# Iteration 30 out of 43.
# Iteration 31 out of 43.
# Iteration 32 out of 43.
# Iteration 33 out of 43.
# Iteration 34 out of 43.
# Iteration 35 out of 43.
# Iteration 36 out of 43.
# Iteration 37 out of 43.
# Iteration 38 out of 43.
# Iteration 39 out of 43.
# Iteration 40 out of 43.
# Iteration 41 out of 43.
# Iteration 42 out of 43.
# Iteration 43 out of 43.
# t_eval 739
# Temperaure Round 17 out of 80.
# Iteration 1 out of 43.
# Iteration 2 out of 43.
# Iteration 3 out of 43.
# Iteration 4 out of 43.
# Iteration 5 out of 43.
# Iteration 6 out of 43.
# Iteration 7 out of 43.
# Iteration 8 out of 43.
# Iteration 9 out of 43.
# Iteration 10 out of 43.
# Iteration 11 out of 43.
# Iteration 12 out of 43.
# Iteration 13 out of 43.
# Iteration 14 out of 43.
# Iteration 15 out of 43.
# Iteration 16 out of 43.
# Iteration 17 out of 43.
# Iteration 18 out of 43.
# Iteration 19 out of 43.
# Iteration 20 out of 43.
# Iteration 21 out of 43.
# Iteration 22 out of 43.
# Iteration 23 out of 43.
# Iteration 24 out of 43.
# Iteration 25 out of 43.
# Iteration 26 out of 43.
# Iteration 27 out of 43.
# Iteration 28 out of 43.
# Iteration 29 out of 43.
# Iteration 30 out of 43.
# Iteration 31 out of 43.
# Iteration 32 out of 43.
# Iteration 33 out of 43.
# Iteration 34 out of 43.
# Iteration 35 out of 43.
# Iteration 36 out of 43.
# Iteration 37 out of 43.
# Iteration 38 out of 43.
# Iteration 39 out of 43.
# Iteration 40 out of 43.
# Iteration 41 out of 43.
# Iteration 42 out of 43.
# Iteration 43 out of 43.
# t_eval 782
# Temperaure Round 18 out of 80.
# Iteration 1 out of 43.
# Iteration 2 out of 43.
# Iteration 3 out of 43.
# Iteration 4 out of 43.
# Iteration 5 out of 43.
# Iteration 6 out of 43.
# Iteration 7 out of 43.
# Iteration 8 out of 43.
# Iteration 9 out of 43.
# Iteration 10 out of 43.
# Iteration 11 out of 43.
# Iteration 12 out of 43.
# Iteration 13 out of 43.
# Iteration 14 out of 43.
# Iteration 15 out of 43.
# Iteration 16 out of 43.
# Iteration 17 out of 43.
# Iteration 18 out of 43.
# Iteration 19 out of 43.
# Iteration 20 out of 43.
# Iteration 21 out of 43.
# Iteration 22 out of 43.
# Iteration 23 out of 43.
# Iteration 24 out of 43.
# Iteration 25 out of 43.
# Iteration 26 out of 43.
# Iteration 27 out of 43.
# Iteration 28 out of 43.
# Iteration 29 out of 43.
# Iteration 30 out of 43.
# Iteration 31 out of 43.
# Iteration 32 out of 43.
# Iteration 33 out of 43.
# Iteration 34 out of 43.
# Iteration 35 out of 43.
# Iteration 36 out of 43.
# Iteration 37 out of 43.
# Iteration 38 out of 43.
# Iteration 39 out of 43.
# Iteration 40 out of 43.
# Iteration 41 out of 43.
# Iteration 42 out of 43.
# Iteration 43 out of 43.
# t_eval 825
# Temperaure Round 19 out of 80.
# Iteration 1 out of 43.
# Iteration 2 out of 43.
# Iteration 3 out of 43.
# Iteration 4 out of 43.
# Iteration 5 out of 43.
# Iteration 6 out of 43.
# Iteration 7 out of 43.
# Iteration 8 out of 43.
# Iteration 9 out of 43.
# Iteration 10 out of 43.
# Iteration 11 out of 43.
# Iteration 12 out of 43.
# Iteration 13 out of 43.
# Iteration 14 out of 43.
# Iteration 15 out of 43.
# Iteration 16 out of 43.
# Iteration 17 out of 43.
# Iteration 18 out of 43.
# Iteration 19 out of 43.
# Iteration 20 out of 43.
# Iteration 21 out of 43.
# Iteration 22 out of 43.
# Iteration 23 out of 43.
# Iteration 24 out of 43.
# Iteration 25 out of 43.
# Iteration 26 out of 43.
# Iteration 27 out of 43.
# Iteration 28 out of 43.
# Iteration 29 out of 43.
# Iteration 30 out of 43.
# Iteration 31 out of 43.
# Iteration 32 out of 43.
# Iteration 33 out of 43.
# Iteration 34 out of 43.
# Iteration 35 out of 43.
# Iteration 36 out of 43.
# Iteration 37 out of 43.
# Iteration 38 out of 43.
# Iteration 39 out of 43.
# Iteration 40 out of 43.
# Iteration 41 out of 43.
# Iteration 42 out of 43.
# Iteration 43 out of 43.
# t_eval 868
# Temperaure Round 20 out of 80.
# Iteration 1 out of 43.
# Iteration 2 out of 43.
# Iteration 3 out of 43.
# Iteration 4 out of 43.
# Iteration 5 out of 43.
# Iteration 6 out of 43.
# Iteration 7 out of 43.
# Iteration 8 out of 43.
# Iteration 9 out of 43.
# Iteration 10 out of 43.
# Iteration 11 out of 43.
# Iteration 12 out of 43.
# Iteration 13 out of 43.
# Iteration 14 out of 43.
# Iteration 15 out of 43.
# Iteration 16 out of 43.
# Iteration 17 out of 43.
# Iteration 18 out of 43.
# Iteration 19 out of 43.
# Iteration 20 out of 43.
# Iteration 21 out of 43.
# Iteration 22 out of 43.
# Iteration 23 out of 43.
# Iteration 24 out of 43.
# Iteration 25 out of 43.
# Iteration 26 out of 43.
# Iteration 27 out of 43.
# Iteration 28 out of 43.
# Iteration 29 out of 43.
# Iteration 30 out of 43.
# Iteration 31 out of 43.
# Iteration 32 out of 43.
# Iteration 33 out of 43.
# Iteration 34 out of 43.
# Iteration 35 out of 43.
# Iteration 36 out of 43.
# Iteration 37 out of 43.
# Iteration 38 out of 43.
# Iteration 39 out of 43.
# Iteration 40 out of 43.
# Iteration 41 out of 43.
# Iteration 42 out of 43.
# Iteration 43 out of 43.
# t_eval 911
# Temperaure Round 21 out of 80.
# Iteration 1 out of 44.
# Iteration 2 out of 44.
# Iteration 3 out of 44.
# Iteration 4 out of 44.
# Iteration 5 out of 44.
# Iteration 6 out of 44.
# Iteration 7 out of 44.
# Iteration 8 out of 44.
# Iteration 9 out of 44.
# Iteration 10 out of 44.
# Iteration 11 out of 44.
# Iteration 12 out of 44.
# Iteration 13 out of 44.
# Iteration 14 out of 44.
# Iteration 15 out of 44.
# Iteration 16 out of 44.
# Iteration 17 out of 44.
# Iteration 18 out of 44.
# Iteration 19 out of 44.
# Iteration 20 out of 44.
# Iteration 21 out of 44.
# Iteration 22 out of 44.
# Iteration 23 out of 44.
# Iteration 24 out of 44.
# Iteration 25 out of 44.
# Iteration 26 out of 44.
# Iteration 27 out of 44.
# Iteration 28 out of 44.
# Iteration 29 out of 44.
# Iteration 30 out of 44.
# Iteration 31 out of 44.
# Iteration 32 out of 44.
# Iteration 33 out of 44.
# Iteration 34 out of 44.
# Iteration 35 out of 44.
# Iteration 36 out of 44.
# Iteration 37 out of 44.
# Iteration 38 out of 44.
# Iteration 39 out of 44.
# Iteration 40 out of 44.
# Iteration 41 out of 44.
# Iteration 42 out of 44.
# Iteration 43 out of 44.
# Iteration 44 out of 44.
# t_eval 955
# Temperaure Round 22 out of 80.
# Iteration 1 out of 44.
# Iteration 2 out of 44.
# Iteration 3 out of 44.
# Iteration 4 out of 44.
# Iteration 5 out of 44.
# Iteration 6 out of 44.
# Iteration 7 out of 44.
# Iteration 8 out of 44.
# Iteration 9 out of 44.
# Iteration 10 out of 44.
# Iteration 11 out of 44.
# Iteration 12 out of 44.
# Iteration 13 out of 44.
# Iteration 14 out of 44.
# Iteration 15 out of 44.
# Iteration 16 out of 44.
# Iteration 17 out of 44.
# Iteration 18 out of 44.
# Iteration 19 out of 44.
# Iteration 20 out of 44.
# Iteration 21 out of 44.
# Iteration 22 out of 44.
# Iteration 23 out of 44.
# Iteration 24 out of 44.
# Iteration 25 out of 44.
# Iteration 26 out of 44.
# Iteration 27 out of 44.
# Iteration 28 out of 44.
# Iteration 29 out of 44.
# Iteration 30 out of 44.
# Iteration 31 out of 44.
# Iteration 32 out of 44.
# Iteration 33 out of 44.
# Iteration 34 out of 44.
# Iteration 35 out of 44.
# Iteration 36 out of 44.
# Iteration 37 out of 44.
# Iteration 38 out of 44.
# Iteration 39 out of 44.
# Iteration 40 out of 44.
# Iteration 41 out of 44.
# Iteration 42 out of 44.
# Iteration 43 out of 44.
# Iteration 44 out of 44.
# t_eval 999
# Temperaure Round 23 out of 80.
# Iteration 1 out of 44.
# Iteration 2 out of 44.
# Iteration 3 out of 44.
# Iteration 4 out of 44.
# Iteration 5 out of 44.
# Iteration 6 out of 44.
# Iteration 7 out of 44.
# Iteration 8 out of 44.
# Iteration 9 out of 44.
# Iteration 10 out of 44.
# Iteration 11 out of 44.
# Iteration 12 out of 44.
# Iteration 13 out of 44.
# Iteration 14 out of 44.
# Iteration 15 out of 44.
# Iteration 16 out of 44.
# Iteration 17 out of 44.
# Iteration 18 out of 44.
# Iteration 19 out of 44.
# Iteration 20 out of 44.
# Iteration 21 out of 44.
# Iteration 22 out of 44.
# Iteration 23 out of 44.
# Iteration 24 out of 44.
# Iteration 25 out of 44.
# Iteration 26 out of 44.
# Iteration 27 out of 44.
# Iteration 28 out of 44.
# Iteration 29 out of 44.
# Iteration 30 out of 44.
# Iteration 31 out of 44.
# Iteration 32 out of 44.
# Iteration 33 out of 44.
# Iteration 34 out of 44.
# Iteration 35 out of 44.
# Iteration 36 out of 44.
# Iteration 37 out of 44.
# Iteration 38 out of 44.
# Iteration 39 out of 44.
# Iteration 40 out of 44.
# Iteration 41 out of 44.
# Iteration 42 out of 44.
# Iteration 43 out of 44.
# Iteration 44 out of 44.
# t_eval 1043
# Temperaure Round 24 out of 80.
# Iteration 1 out of 44.
# Iteration 2 out of 44.
# Iteration 3 out of 44.
# Iteration 4 out of 44.
# Iteration 5 out of 44.
# Iteration 6 out of 44.
# Iteration 7 out of 44.
# Iteration 8 out of 44.
# Iteration 9 out of 44.
# Iteration 10 out of 44.
# Iteration 11 out of 44.
# Iteration 12 out of 44.
# Iteration 13 out of 44.
# Iteration 14 out of 44.
# Iteration 15 out of 44.
# Iteration 16 out of 44.
# Iteration 17 out of 44.
# Iteration 18 out of 44.
# Iteration 19 out of 44.
# Iteration 20 out of 44.
# Iteration 21 out of 44.
# Iteration 22 out of 44.
# Iteration 23 out of 44.
# Iteration 24 out of 44.
# Iteration 25 out of 44.
# Iteration 26 out of 44.
# Iteration 27 out of 44.
# Iteration 28 out of 44.
# Iteration 29 out of 44.
# Iteration 30 out of 44.
# Iteration 31 out of 44.
# Iteration 32 out of 44.
# Iteration 33 out of 44.
# Iteration 34 out of 44.
# Iteration 35 out of 44.
# Iteration 36 out of 44.
# Iteration 37 out of 44.
# Iteration 38 out of 44.
# Iteration 39 out of 44.
# Iteration 40 out of 44.
# Iteration 41 out of 44.
# Iteration 42 out of 44.
# Iteration 43 out of 44.
# Iteration 44 out of 44.
# t_eval 1087
# Temperaure Round 25 out of 80.
# Iteration 1 out of 45.
# Iteration 2 out of 45.
# Iteration 3 out of 45.
# Iteration 4 out of 45.
# Iteration 5 out of 45.
# Iteration 6 out of 45.
# Iteration 7 out of 45.
# Iteration 8 out of 45.
# Iteration 9 out of 45.
# Iteration 10 out of 45.
# Iteration 11 out of 45.
# Iteration 12 out of 45.
# Iteration 13 out of 45.
# Iteration 14 out of 45.
# Iteration 15 out of 45.
# Iteration 16 out of 45.
# Iteration 17 out of 45.
# Iteration 18 out of 45.
# Iteration 19 out of 45.
# Iteration 20 out of 45.
# Iteration 21 out of 45.
# Iteration 22 out of 45.
# Iteration 23 out of 45.
# Iteration 24 out of 45.
# Iteration 25 out of 45.
# Iteration 26 out of 45.
# Iteration 27 out of 45.
# Iteration 28 out of 45.
# Iteration 29 out of 45.
# Iteration 30 out of 45.
# Iteration 31 out of 45.
# Iteration 32 out of 45.
# Iteration 33 out of 45.
# Iteration 34 out of 45.
# Iteration 35 out of 45.
# Iteration 36 out of 45.
# Iteration 37 out of 45.
# Iteration 38 out of 45.
# Iteration 39 out of 45.
# Iteration 40 out of 45.
# Iteration 41 out of 45.
# Iteration 42 out of 45.
# Iteration 43 out of 45.
# Iteration 44 out of 45.
# Iteration 45 out of 45.
# t_eval 1132
# Temperaure Round 26 out of 80.
# Iteration 1 out of 45.
# Iteration 2 out of 45.
# Iteration 3 out of 45.
# Iteration 4 out of 45.
# Iteration 5 out of 45.
# Iteration 6 out of 45.
# Iteration 7 out of 45.
# Iteration 8 out of 45.
# Iteration 9 out of 45.
# Iteration 10 out of 45.
# Iteration 11 out of 45.
# Iteration 12 out of 45.
# Iteration 13 out of 45.
# Iteration 14 out of 45.
# Iteration 15 out of 45.
# Iteration 16 out of 45.
# Iteration 17 out of 45.
# Iteration 18 out of 45.
# Iteration 19 out of 45.
# Iteration 20 out of 45.
# Iteration 21 out of 45.
# Iteration 22 out of 45.
# Iteration 23 out of 45.
# Iteration 24 out of 45.
# Iteration 25 out of 45.
# Iteration 26 out of 45.
# Iteration 27 out of 45.
# Iteration 28 out of 45.
# Iteration 29 out of 45.
# Iteration 30 out of 45.
# Iteration 31 out of 45.
# Iteration 32 out of 45.
# Iteration 33 out of 45.
# Iteration 34 out of 45.
# Iteration 35 out of 45.
# Iteration 36 out of 45.
# Iteration 37 out of 45.
# Iteration 38 out of 45.
# Iteration 39 out of 45.
# Iteration 40 out of 45.
# Iteration 41 out of 45.
# Iteration 42 out of 45.
# Iteration 43 out of 45.
# Iteration 44 out of 45.
# Iteration 45 out of 45.
# t_eval 1177
# Temperaure Round 27 out of 80.
# Iteration 1 out of 45.
# Iteration 2 out of 45.
# Iteration 3 out of 45.
# Iteration 4 out of 45.
# Iteration 5 out of 45.
# Iteration 6 out of 45.
# Iteration 7 out of 45.
# Iteration 8 out of 45.
# Iteration 9 out of 45.
# Iteration 10 out of 45.
# Iteration 11 out of 45.
# Iteration 12 out of 45.
# Iteration 13 out of 45.
# Iteration 14 out of 45.
# Iteration 15 out of 45.
# Iteration 16 out of 45.
# Iteration 17 out of 45.
# Iteration 18 out of 45.
# Iteration 19 out of 45.
# Iteration 20 out of 45.
# Iteration 21 out of 45.
# Iteration 22 out of 45.
# Iteration 23 out of 45.
# Iteration 24 out of 45.
# Iteration 25 out of 45.
# Iteration 26 out of 45.
# Iteration 27 out of 45.
# Iteration 28 out of 45.
# Iteration 29 out of 45.
# Iteration 30 out of 45.
# Iteration 31 out of 45.
# Iteration 32 out of 45.
# Iteration 33 out of 45.
# Iteration 34 out of 45.
# Iteration 35 out of 45.
# Iteration 36 out of 45.
# Iteration 37 out of 45.
# Iteration 38 out of 45.
# Iteration 39 out of 45.
# Iteration 40 out of 45.
# Iteration 41 out of 45.
# Iteration 42 out of 45.
# Iteration 43 out of 45.
# Iteration 44 out of 45.
# Iteration 45 out of 45.
# t_eval 1222
# Temperaure Round 28 out of 80.
# Iteration 1 out of 45.
# Iteration 2 out of 45.
# Iteration 3 out of 45.
# Iteration 4 out of 45.
# Iteration 5 out of 45.
# Iteration 6 out of 45.
# Iteration 7 out of 45.
# Iteration 8 out of 45.
# Iteration 9 out of 45.
# Iteration 10 out of 45.
# Iteration 11 out of 45.
# Iteration 12 out of 45.
# Iteration 13 out of 45.
# Iteration 14 out of 45.
# Iteration 15 out of 45.
# Iteration 16 out of 45.
# Iteration 17 out of 45.
# Iteration 18 out of 45.
# Iteration 19 out of 45.
# Iteration 20 out of 45.
# Iteration 21 out of 45.
# Iteration 22 out of 45.
# Iteration 23 out of 45.
# Iteration 24 out of 45.
# Iteration 25 out of 45.
# Iteration 26 out of 45.
# Iteration 27 out of 45.
# Iteration 28 out of 45.
# Iteration 29 out of 45.
# Iteration 30 out of 45.
# Iteration 31 out of 45.
# Iteration 32 out of 45.
# Iteration 33 out of 45.
# Iteration 34 out of 45.
# Iteration 35 out of 45.
# Iteration 36 out of 45.
# Iteration 37 out of 45.
# Iteration 38 out of 45.
# Iteration 39 out of 45.
# Iteration 40 out of 45.
# Iteration 41 out of 45.
# Iteration 42 out of 45.
# Iteration 43 out of 45.
# Iteration 44 out of 45.
# Iteration 45 out of 45.
# t_eval 1267
# Temperaure Round 29 out of 80.
# Iteration 1 out of 45.
# Iteration 2 out of 45.
# Iteration 3 out of 45.
# Iteration 4 out of 45.
# Iteration 5 out of 45.
# Iteration 6 out of 45.
# Iteration 7 out of 45.
# Iteration 8 out of 45.
# Iteration 9 out of 45.
# Iteration 10 out of 45.
# Iteration 11 out of 45.
# Iteration 12 out of 45.
# Iteration 13 out of 45.
# Iteration 14 out of 45.
# Iteration 15 out of 45.
# Iteration 16 out of 45.
# Iteration 17 out of 45.
# Iteration 18 out of 45.
# Iteration 19 out of 45.
# Iteration 20 out of 45.
# Iteration 21 out of 45.
# Iteration 22 out of 45.
# Iteration 23 out of 45.
# Iteration 24 out of 45.
# Iteration 25 out of 45.
# Iteration 26 out of 45.
# Iteration 27 out of 45.
# Iteration 28 out of 45.
# Iteration 29 out of 45.
# Iteration 30 out of 45.
# Iteration 31 out of 45.
# Iteration 32 out of 45.
# Iteration 33 out of 45.
# Iteration 34 out of 45.
# Iteration 35 out of 45.
# Iteration 36 out of 45.
# Iteration 37 out of 45.
# Iteration 38 out of 45.
# Iteration 39 out of 45.
# Iteration 40 out of 45.
# Iteration 41 out of 45.
# Iteration 42 out of 45.
# Iteration 43 out of 45.
# Iteration 44 out of 45.
# Iteration 45 out of 45.
# t_eval 1312
# Temperaure Round 30 out of 80.
# Iteration 1 out of 46.
# Iteration 2 out of 46.
# Iteration 3 out of 46.
# Iteration 4 out of 46.
# Iteration 5 out of 46.
# Iteration 6 out of 46.
# Iteration 7 out of 46.
# Iteration 8 out of 46.
# Iteration 9 out of 46.
# Iteration 10 out of 46.
# Iteration 11 out of 46.
# Iteration 12 out of 46.
# Iteration 13 out of 46.
# Iteration 14 out of 46.
# Iteration 15 out of 46.
# Iteration 16 out of 46.
# Iteration 17 out of 46.
# Iteration 18 out of 46.
# Iteration 19 out of 46.
# Iteration 20 out of 46.
# Iteration 21 out of 46.
# Iteration 22 out of 46.
# Iteration 23 out of 46.
# Iteration 24 out of 46.
# Iteration 25 out of 46.
# Iteration 26 out of 46.
# Iteration 27 out of 46.
# Iteration 28 out of 46.
# Iteration 29 out of 46.
# Iteration 30 out of 46.
# Iteration 31 out of 46.
# Iteration 32 out of 46.
# Iteration 33 out of 46.
# Iteration 34 out of 46.
# Iteration 35 out of 46.
# Iteration 36 out of 46.
# Iteration 37 out of 46.
# Iteration 38 out of 46.
# Iteration 39 out of 46.
# Iteration 40 out of 46.
# Iteration 41 out of 46.
# Iteration 42 out of 46.
# Iteration 43 out of 46.
# Iteration 44 out of 46.
# Iteration 45 out of 46.
# Iteration 46 out of 46.
# t_eval 1358
# Temperaure Round 31 out of 80.
# Iteration 1 out of 46.
# Iteration 2 out of 46.
# Iteration 3 out of 46.
# Iteration 4 out of 46.
# Iteration 5 out of 46.
# Iteration 6 out of 46.
# Iteration 7 out of 46.
# Iteration 8 out of 46.
# Iteration 9 out of 46.
# Iteration 10 out of 46.
# Iteration 11 out of 46.
# Iteration 12 out of 46.
# Iteration 13 out of 46.
# Iteration 14 out of 46.
# Iteration 15 out of 46.
# Iteration 16 out of 46.
# Iteration 17 out of 46.
# Iteration 18 out of 46.
# Iteration 19 out of 46.
# Iteration 20 out of 46.
# Iteration 21 out of 46.
# Iteration 22 out of 46.
# Iteration 23 out of 46.
# Iteration 24 out of 46.
# Iteration 25 out of 46.
# Iteration 26 out of 46.
# Iteration 27 out of 46.
# Iteration 28 out of 46.
# Iteration 29 out of 46.
# Iteration 30 out of 46.
# Iteration 31 out of 46.
# Iteration 32 out of 46.
# Iteration 33 out of 46.
# Iteration 34 out of 46.
# Iteration 35 out of 46.
# Iteration 36 out of 46.
# Iteration 37 out of 46.
# Iteration 38 out of 46.
# Iteration 39 out of 46.
# Iteration 40 out of 46.
# Iteration 41 out of 46.
# Iteration 42 out of 46.
# Iteration 43 out of 46.
# Iteration 44 out of 46.
# Iteration 45 out of 46.
# Iteration 46 out of 46.
# t_eval 1404
# Temperaure Round 32 out of 80.
# Iteration 1 out of 46.
# Iteration 2 out of 46.
# Iteration 3 out of 46.
# Iteration 4 out of 46.
# Iteration 5 out of 46.
# Iteration 6 out of 46.
# Iteration 7 out of 46.
# Iteration 8 out of 46.
# Iteration 9 out of 46.
# Iteration 10 out of 46.
# Iteration 11 out of 46.
# Iteration 12 out of 46.
# Iteration 13 out of 46.
# Iteration 14 out of 46.
# Iteration 15 out of 46.
# Iteration 16 out of 46.
# Iteration 17 out of 46.
# Iteration 18 out of 46.
# Iteration 19 out of 46.
# Iteration 20 out of 46.
# Iteration 21 out of 46.
# Iteration 22 out of 46.
# Iteration 23 out of 46.
# Iteration 24 out of 46.
# Iteration 25 out of 46.
# Iteration 26 out of 46.
# Iteration 27 out of 46.
# Iteration 28 out of 46.
# Iteration 29 out of 46.
# Iteration 30 out of 46.
# Iteration 31 out of 46.
# Iteration 32 out of 46.
# Iteration 33 out of 46.
# Iteration 34 out of 46.
# Iteration 35 out of 46.
# Iteration 36 out of 46.
# Iteration 37 out of 46.
# Iteration 38 out of 46.
# Iteration 39 out of 46.
# Iteration 40 out of 46.
# Iteration 41 out of 46.
# Iteration 42 out of 46.
# Iteration 43 out of 46.
# Iteration 44 out of 46.
# Iteration 45 out of 46.
# Iteration 46 out of 46.
# t_eval 1450
# Temperaure Round 33 out of 80.
# Iteration 1 out of 46.
# Iteration 2 out of 46.
# Iteration 3 out of 46.
# Iteration 4 out of 46.
# Iteration 5 out of 46.
# Iteration 6 out of 46.
# Iteration 7 out of 46.
# Iteration 8 out of 46.
# Iteration 9 out of 46.
# Iteration 10 out of 46.
# Iteration 11 out of 46.
# Iteration 12 out of 46.
# Iteration 13 out of 46.
# Iteration 14 out of 46.
# Iteration 15 out of 46.
# Iteration 16 out of 46.
# Iteration 17 out of 46.
# Iteration 18 out of 46.
# Iteration 19 out of 46.
# Iteration 20 out of 46.
# Iteration 21 out of 46.
# Iteration 22 out of 46.
# Iteration 23 out of 46.
# Iteration 24 out of 46.
# Iteration 25 out of 46.
# Iteration 26 out of 46.
# Iteration 27 out of 46.
# Iteration 28 out of 46.
# Iteration 29 out of 46.
# Iteration 30 out of 46.
# Iteration 31 out of 46.
# Iteration 32 out of 46.
# Iteration 33 out of 46.
# Iteration 34 out of 46.
# Iteration 35 out of 46.
# Iteration 36 out of 46.
# Iteration 37 out of 46.
# Iteration 38 out of 46.
# Iteration 39 out of 46.
# Iteration 40 out of 46.
# Iteration 41 out of 46.
# Iteration 42 out of 46.
# Iteration 43 out of 46.
# Iteration 44 out of 46.
# Iteration 45 out of 46.
# Iteration 46 out of 46.
# t_eval 1496
# Temperaure Round 34 out of 80.
# Iteration 1 out of 47.
# Iteration 2 out of 47.
# Iteration 3 out of 47.
# Iteration 4 out of 47.
# Iteration 5 out of 47.
# Iteration 6 out of 47.
# Iteration 7 out of 47.
# Iteration 8 out of 47.
# Iteration 9 out of 47.
# Iteration 10 out of 47.
# Iteration 11 out of 47.
# Iteration 12 out of 47.
# Iteration 13 out of 47.
# Iteration 14 out of 47.
# Iteration 15 out of 47.
# Iteration 16 out of 47.
# Iteration 17 out of 47.
# Iteration 18 out of 47.
# Iteration 19 out of 47.
# Iteration 20 out of 47.
# Iteration 21 out of 47.
# Iteration 22 out of 47.
# Iteration 23 out of 47.
# Iteration 24 out of 47.
# Iteration 25 out of 47.
# Iteration 26 out of 47.
# Iteration 27 out of 47.
# Iteration 28 out of 47.
# Iteration 29 out of 47.
# Iteration 30 out of 47.
# Iteration 31 out of 47.
# Iteration 32 out of 47.
# Iteration 33 out of 47.
# Iteration 34 out of 47.
# Iteration 35 out of 47.
# Iteration 36 out of 47.
# Iteration 37 out of 47.
# Iteration 38 out of 47.
# Iteration 39 out of 47.
# Iteration 40 out of 47.
# Iteration 41 out of 47.
# Iteration 42 out of 47.
# Iteration 43 out of 47.
# Iteration 44 out of 47.
# Iteration 45 out of 47.
# Iteration 46 out of 47.
# Iteration 47 out of 47.
# t_eval 1543
# Temperaure Round 35 out of 80.
# Iteration 1 out of 47.
# Iteration 2 out of 47.
# Iteration 3 out of 47.
# Iteration 4 out of 47.
# Iteration 5 out of 47.
# Iteration 6 out of 47.
# Iteration 7 out of 47.
# Iteration 8 out of 47.
# Iteration 9 out of 47.
# Iteration 10 out of 47.
# Iteration 11 out of 47.
# Iteration 12 out of 47.
# Iteration 13 out of 47.
# Iteration 14 out of 47.
# Iteration 15 out of 47.
# Iteration 16 out of 47.
# Iteration 17 out of 47.
# Iteration 18 out of 47.
# Iteration 19 out of 47.
# Iteration 20 out of 47.
# Iteration 21 out of 47.
# Iteration 22 out of 47.
# Iteration 23 out of 47.
# Iteration 24 out of 47.
# Iteration 25 out of 47.
# Iteration 26 out of 47.
# Iteration 27 out of 47.
# Iteration 28 out of 47.
# Iteration 29 out of 47.
# Iteration 30 out of 47.
# Iteration 31 out of 47.
# Iteration 32 out of 47.
# Iteration 33 out of 47.
# Iteration 34 out of 47.
# Iteration 35 out of 47.
# Iteration 36 out of 47.
# Iteration 37 out of 47.
# Iteration 38 out of 47.
# Iteration 39 out of 47.
# Iteration 40 out of 47.
# Iteration 41 out of 47.
# Iteration 42 out of 47.
# Iteration 43 out of 47.
# Iteration 44 out of 47.
# Iteration 45 out of 47.
# Iteration 46 out of 47.
# Iteration 47 out of 47.
# t_eval 1590
# Temperaure Round 36 out of 80.
# Iteration 1 out of 47.
# Iteration 2 out of 47.
# Iteration 3 out of 47.
# Iteration 4 out of 47.
# Iteration 5 out of 47.
# Iteration 6 out of 47.
# Iteration 7 out of 47.
# Iteration 8 out of 47.
# Iteration 9 out of 47.
# Iteration 10 out of 47.
# Iteration 11 out of 47.
# Iteration 12 out of 47.
# Iteration 13 out of 47.
# Iteration 14 out of 47.
# Iteration 15 out of 47.
# Iteration 16 out of 47.
# Iteration 17 out of 47.
# Iteration 18 out of 47.
# Iteration 19 out of 47.
# Iteration 20 out of 47.
# Iteration 21 out of 47.
# Iteration 22 out of 47.
# Iteration 23 out of 47.
# Iteration 24 out of 47.
# Iteration 25 out of 47.
# Iteration 26 out of 47.
# Iteration 27 out of 47.
# Iteration 28 out of 47.
# Iteration 29 out of 47.
# Iteration 30 out of 47.
# Iteration 31 out of 47.
# Iteration 32 out of 47.
# Iteration 33 out of 47.
# Iteration 34 out of 47.
# Iteration 35 out of 47.
# Iteration 36 out of 47.
# Iteration 37 out of 47.
# Iteration 38 out of 47.
# Iteration 39 out of 47.
# Iteration 40 out of 47.
# Iteration 41 out of 47.
# Iteration 42 out of 47.
# Iteration 43 out of 47.
# Iteration 44 out of 47.
# Iteration 45 out of 47.
# Iteration 46 out of 47.
# Iteration 47 out of 47.
# t_eval 1637
# Temperaure Round 37 out of 80.
# Iteration 1 out of 47.
# Iteration 2 out of 47.
# Iteration 3 out of 47.
# Iteration 4 out of 47.
# Iteration 5 out of 47.
# Iteration 6 out of 47.
# Iteration 7 out of 47.
# Iteration 8 out of 47.
# Iteration 9 out of 47.
# Iteration 10 out of 47.
# Iteration 11 out of 47.
# Iteration 12 out of 47.
# Iteration 13 out of 47.
# Iteration 14 out of 47.
# Iteration 15 out of 47.
# Iteration 16 out of 47.
# Iteration 17 out of 47.
# Iteration 18 out of 47.
# Iteration 19 out of 47.
# Iteration 20 out of 47.
# Iteration 21 out of 47.
# Iteration 22 out of 47.
# Iteration 23 out of 47.
# Iteration 24 out of 47.
# Iteration 25 out of 47.
# Iteration 26 out of 47.
# Iteration 27 out of 47.
# Iteration 28 out of 47.
# Iteration 29 out of 47.
# Iteration 30 out of 47.
# Iteration 31 out of 47.
# Iteration 32 out of 47.
# Iteration 33 out of 47.
# Iteration 34 out of 47.
# Iteration 35 out of 47.
# Iteration 36 out of 47.
# Iteration 37 out of 47.
# Iteration 38 out of 47.
# Iteration 39 out of 47.
# Iteration 40 out of 47.
# Iteration 41 out of 47.
# Iteration 42 out of 47.
# Iteration 43 out of 47.
# Iteration 44 out of 47.
# Iteration 45 out of 47.
# Iteration 46 out of 47.
# Iteration 47 out of 47.
# t_eval 1684
# Temperaure Round 38 out of 80.
# Iteration 1 out of 48.
# Iteration 2 out of 48.
# Iteration 3 out of 48.
# Iteration 4 out of 48.
# Iteration 5 out of 48.
# Iteration 6 out of 48.
# Iteration 7 out of 48.
# Iteration 8 out of 48.
# Iteration 9 out of 48.
# Iteration 10 out of 48.
# Iteration 11 out of 48.
# Iteration 12 out of 48.
# Iteration 13 out of 48.
# Iteration 14 out of 48.
# Iteration 15 out of 48.
# Iteration 16 out of 48.
# Iteration 17 out of 48.
# Iteration 18 out of 48.
# Iteration 19 out of 48.
# Iteration 20 out of 48.
# Iteration 21 out of 48.
# Iteration 22 out of 48.
# Iteration 23 out of 48.
# Iteration 24 out of 48.
# Iteration 25 out of 48.
# Iteration 26 out of 48.
# Iteration 27 out of 48.
# Iteration 28 out of 48.
# Iteration 29 out of 48.
# Iteration 30 out of 48.
# Iteration 31 out of 48.
# Iteration 32 out of 48.
# Iteration 33 out of 48.
# Iteration 34 out of 48.
# Iteration 35 out of 48.
# Iteration 36 out of 48.
# Iteration 37 out of 48.
# Iteration 38 out of 48.
# Iteration 39 out of 48.
# Iteration 40 out of 48.
# Iteration 41 out of 48.
# Iteration 42 out of 48.
# Iteration 43 out of 48.
# Iteration 44 out of 48.
# Iteration 45 out of 48.
# Iteration 46 out of 48.
# Iteration 47 out of 48.
# Iteration 48 out of 48.
# t_eval 1732
# Temperaure Round 39 out of 80.
# Iteration 1 out of 48.
# Iteration 2 out of 48.
# Iteration 3 out of 48.
# Iteration 4 out of 48.
# Iteration 5 out of 48.
# Iteration 6 out of 48.
# Iteration 7 out of 48.
# Iteration 8 out of 48.
# Iteration 9 out of 48.
# Iteration 10 out of 48.
# Iteration 11 out of 48.
# Iteration 12 out of 48.
# Iteration 13 out of 48.
# Iteration 14 out of 48.
# Iteration 15 out of 48.
# Iteration 16 out of 48.
# Iteration 17 out of 48.
# Iteration 18 out of 48.
# Iteration 19 out of 48.
# Iteration 20 out of 48.
# Iteration 21 out of 48.
# Iteration 22 out of 48.
# Iteration 23 out of 48.
# Iteration 24 out of 48.
# Iteration 25 out of 48.
# Iteration 26 out of 48.
# Iteration 27 out of 48.
# Iteration 28 out of 48.
# Iteration 29 out of 48.
# Iteration 30 out of 48.
# Iteration 31 out of 48.
# Iteration 32 out of 48.
# Iteration 33 out of 48.
# Iteration 34 out of 48.
# Iteration 35 out of 48.
# Iteration 36 out of 48.
# Iteration 37 out of 48.
# Iteration 38 out of 48.
# Iteration 39 out of 48.
# Iteration 40 out of 48.
# Iteration 41 out of 48.
# Iteration 42 out of 48.
# Iteration 43 out of 48.
# Iteration 44 out of 48.
# Iteration 45 out of 48.
# Iteration 46 out of 48.
# Iteration 47 out of 48.
# Iteration 48 out of 48.
# t_eval 1780
# Temperaure Round 40 out of 80.
# Iteration 1 out of 48.
# Iteration 2 out of 48.
# Iteration 3 out of 48.
# Iteration 4 out of 48.
# Iteration 5 out of 48.
# Iteration 6 out of 48.
# Iteration 7 out of 48.
# Iteration 8 out of 48.
# Iteration 9 out of 48.
# Iteration 10 out of 48.
# Iteration 11 out of 48.
# Iteration 12 out of 48.
# Iteration 13 out of 48.
# Iteration 14 out of 48.
# Iteration 15 out of 48.
# Iteration 16 out of 48.
# Iteration 17 out of 48.
# Iteration 18 out of 48.
# Iteration 19 out of 48.
# Iteration 20 out of 48.
# Iteration 21 out of 48.
# Iteration 22 out of 48.
# Iteration 23 out of 48.
# Iteration 24 out of 48.
# Iteration 25 out of 48.
# Iteration 26 out of 48.
# Iteration 27 out of 48.
# Iteration 28 out of 48.
# Iteration 29 out of 48.
# Iteration 30 out of 48.
# Iteration 31 out of 48.
# Iteration 32 out of 48.
# Iteration 33 out of 48.
# Iteration 34 out of 48.
# Iteration 35 out of 48.
# Iteration 36 out of 48.
# Iteration 37 out of 48.
# Iteration 38 out of 48.
# Iteration 39 out of 48.
# Iteration 40 out of 48.
# Iteration 41 out of 48.
# Iteration 42 out of 48.
# Iteration 43 out of 48.
# Iteration 44 out of 48.
# Iteration 45 out of 48.
# Iteration 46 out of 48.
# Iteration 47 out of 48.
# Iteration 48 out of 48.
# t_eval 1828
# Temperaure Round 41 out of 80.
# Iteration 1 out of 48.
# Iteration 2 out of 48.
# Iteration 3 out of 48.
# Iteration 4 out of 48.
# Iteration 5 out of 48.
# Iteration 6 out of 48.
# Iteration 7 out of 48.
# Iteration 8 out of 48.
# Iteration 9 out of 48.
# Iteration 10 out of 48.
# Iteration 11 out of 48.
# Iteration 12 out of 48.
# Iteration 13 out of 48.
# Iteration 14 out of 48.
# Iteration 15 out of 48.
# Iteration 16 out of 48.
# Iteration 17 out of 48.
# Iteration 18 out of 48.
# Iteration 19 out of 48.
# Iteration 20 out of 48.
# Iteration 21 out of 48.
# Iteration 22 out of 48.
# Iteration 23 out of 48.
# Iteration 24 out of 48.
# Iteration 25 out of 48.
# Iteration 26 out of 48.
# Iteration 27 out of 48.
# Iteration 28 out of 48.
# Iteration 29 out of 48.
# Iteration 30 out of 48.
# Iteration 31 out of 48.
# Iteration 32 out of 48.
# Iteration 33 out of 48.
# Iteration 34 out of 48.
# Iteration 35 out of 48.
# Iteration 36 out of 48.
# Iteration 37 out of 48.
# Iteration 38 out of 48.
# Iteration 39 out of 48.
# Iteration 40 out of 48.
# Iteration 41 out of 48.
# Iteration 42 out of 48.
# Iteration 43 out of 48.
# Iteration 44 out of 48.
# Iteration 45 out of 48.
# Iteration 46 out of 48.
# Iteration 47 out of 48.
# Iteration 48 out of 48.
# t_eval 1876
# Temperaure Round 42 out of 80.
# Iteration 1 out of 49.
# Iteration 2 out of 49.
# Iteration 3 out of 49.
# Iteration 4 out of 49.
# Iteration 5 out of 49.
# Iteration 6 out of 49.
# Iteration 7 out of 49.
# Iteration 8 out of 49.
# Iteration 9 out of 49.
# Iteration 10 out of 49.
# Iteration 11 out of 49.
# Iteration 12 out of 49.
# Iteration 13 out of 49.
# Iteration 14 out of 49.
# Iteration 15 out of 49.
# Iteration 16 out of 49.
# Iteration 17 out of 49.
# Iteration 18 out of 49.
# Iteration 19 out of 49.
# Iteration 20 out of 49.
# ...
# Iteration 15 out of 56.
# Iteration 16 out of 56.
# Iteration 17 out of 56.
# Iteration 18 out of 56.
# Iteration 19 out of 56.
# Iteration 20 out of 56.
# Iteration 21 out of 56.
# Iteration 22 out of 56.
# Iteration 23 out of 56.
# Iteration 24 out of 56.
# Iteration 25 out of 56.
# Iteration 26 out of 56.
# Iteration 27 out of 56.
# Iteration 28 out of 56.
# Iteration 29 out of 56.
# Iteration 30 out of 56.
# Iteration 31 out of 56.
# Iteration 32 out of 56.
# Iteration 33 out of 56.
# Iteration 34 out of 56.
# Iteration 35 out of 56.
# Iteration 36 out of 56.
# Iteration 37 out of 56.
# Iteration 38 out of 56.
# Iteration 39 out of 56.
# Iteration 40 out of 56.
# Iteration 41 out of 56.
# Iteration 42 out of 56.
# Iteration 43 out of 56.
# Iteration 44 out of 56.
# Iteration 45 out of 56.
# Iteration 46 out of 56.
# Iteration 47 out of 56.
# Iteration 48 out of 56.
# Iteration 49 out of 56.
# Iteration 50 out of 56.
# Iteration 51 out of 56.
# Iteration 52 out of 56.
# Iteration 53 out of 56.
# Iteration 54 out of 56.
# Iteration 55 out of 56.
# Iteration 56 out of 56.
# t_eval 3390
# Temperaure Round 71 out of 80.
# Iteration 1 out of 56.
# Iteration 2 out of 56.
# Iteration 3 out of 56.
# Iteration 4 out of 56.
# Iteration 5 out of 56.
# Iteration 6 out of 56.
# Iteration 7 out of 56.
# Iteration 8 out of 56.
# Iteration 9 out of 56.
# Iteration 10 out of 56.
# Iteration 11 out of 56.
# Iteration 12 out of 56.
# Iteration 13 out of 56.
# Iteration 14 out of 56.
# Iteration 15 out of 56.
# Iteration 16 out of 56.
# Iteration 17 out of 56.
# Iteration 18 out of 56.
# Iteration 19 out of 56.
# Iteration 20 out of 56.
# Iteration 21 out of 56.
# Iteration 22 out of 56.
# Iteration 23 out of 56.
# Iteration 24 out of 56.
# Iteration 25 out of 56.
# Iteration 26 out of 56.
# Iteration 27 out of 56.
# Iteration 28 out of 56.
# Iteration 29 out of 56.
# Iteration 30 out of 56.
# Iteration 31 out of 56.
# Iteration 32 out of 56.
# Iteration 33 out of 56.
# Iteration 34 out of 56.
# Iteration 35 out of 56.
# Iteration 36 out of 56.
# Iteration 37 out of 56.
# Iteration 38 out of 56.
# Iteration 39 out of 56.
# Iteration 40 out of 56.
# Iteration 41 out of 56.
# Iteration 42 out of 56.
# Iteration 43 out of 56.
# Iteration 44 out of 56.
# Iteration 45 out of 56.
# Iteration 46 out of 56.
# Iteration 47 out of 56.
# Iteration 48 out of 56.
# Iteration 49 out of 56.
# Iteration 50 out of 56.
# Iteration 51 out of 56.
# Iteration 52 out of 56.
# Iteration 53 out of 56.
# Iteration 54 out of 56.
# Iteration 55 out of 56.
# Iteration 56 out of 56.
# t_eval 3446
# Temperaure Round 72 out of 80.
# Iteration 1 out of 56.
# Iteration 2 out of 56.
# Iteration 3 out of 56.
# Iteration 4 out of 56.
# Iteration 5 out of 56.
# Iteration 6 out of 56.
# Iteration 7 out of 56.
# Iteration 8 out of 56.
# Iteration 9 out of 56.
# Iteration 10 out of 56.
# Iteration 11 out of 56.
# Iteration 12 out of 56.
# Iteration 13 out of 56.
# Iteration 14 out of 56.
# Iteration 15 out of 56.
# Iteration 16 out of 56.
# Iteration 17 out of 56.
# Iteration 18 out of 56.
# Iteration 19 out of 56.
# Iteration 20 out of 56.
# Iteration 21 out of 56.
# Iteration 22 out of 56.
# Iteration 23 out of 56.
# Iteration 24 out of 56.
# Iteration 25 out of 56.
# Iteration 26 out of 56.
# Iteration 27 out of 56.
# Iteration 28 out of 56.
# Iteration 29 out of 56.
# Iteration 30 out of 56.
# Iteration 31 out of 56.
# Iteration 32 out of 56.
# Iteration 33 out of 56.
# Iteration 34 out of 56.
# Iteration 35 out of 56.
# Iteration 36 out of 56.
# Iteration 37 out of 56.
# Iteration 38 out of 56.
# Iteration 39 out of 56.
# Iteration 40 out of 56.
# Iteration 41 out of 56.
# Iteration 42 out of 56.
# Iteration 43 out of 56.
# Iteration 44 out of 56.
# Iteration 45 out of 56.
# Iteration 46 out of 56.
# Iteration 47 out of 56.
# Iteration 48 out of 56.
# Iteration 49 out of 56.
# Iteration 50 out of 56.
# Iteration 51 out of 56.
# Iteration 52 out of 56.
# Iteration 53 out of 56.
# Iteration 54 out of 56.
# Iteration 55 out of 56.
# Iteration 56 out of 56.
# t_eval 3502
# Temperaure Round 73 out of 80.
# Iteration 1 out of 57.
# Iteration 2 out of 57.
# Iteration 3 out of 57.
# Iteration 4 out of 57.
# Iteration 5 out of 57.
# Iteration 6 out of 57.
# Iteration 7 out of 57.
# Iteration 8 out of 57.
# Iteration 9 out of 57.
# Iteration 10 out of 57.
# Iteration 11 out of 57.
# Iteration 12 out of 57.
# Iteration 13 out of 57.
# Iteration 14 out of 57.
# Iteration 15 out of 57.
# Iteration 16 out of 57.
# Iteration 17 out of 57.
# Iteration 18 out of 57.
# Iteration 19 out of 57.
# Iteration 20 out of 57.
# Iteration 21 out of 57.
# Iteration 22 out of 57.
# Iteration 23 out of 57.
# Iteration 24 out of 57.
# Iteration 25 out of 57.
# Iteration 26 out of 57.
# Iteration 27 out of 57.
# Iteration 28 out of 57.
# Iteration 29 out of 57.
# Iteration 30 out of 57.
# Iteration 31 out of 57.
# Iteration 32 out of 57.
# Iteration 33 out of 57.
# Iteration 34 out of 57.
# Iteration 35 out of 57.
# Iteration 36 out of 57.
# Iteration 37 out of 57.
# Iteration 38 out of 57.
# Iteration 39 out of 57.
# Iteration 40 out of 57.
# Iteration 41 out of 57.
# Iteration 42 out of 57.
# Iteration 43 out of 57.
# Iteration 44 out of 57.
# Iteration 45 out of 57.
# Iteration 46 out of 57.
# Iteration 47 out of 57.
# Iteration 48 out of 57.
# Iteration 49 out of 57.
# Iteration 50 out of 57.
# Iteration 51 out of 57.
# Iteration 52 out of 57.
# Iteration 53 out of 57.
# Iteration 54 out of 57.
# Iteration 55 out of 57.
# Iteration 56 out of 57.
# Iteration 57 out of 57.
# t_eval 3559
# Temperaure Round 74 out of 80.
# Iteration 1 out of 57.
# Iteration 2 out of 57.
# Iteration 3 out of 57.
# Iteration 4 out of 57.
# Iteration 5 out of 57.
# Iteration 6 out of 57.
# Iteration 7 out of 57.
# Iteration 8 out of 57.
# Iteration 9 out of 57.
# Iteration 10 out of 57.
# Iteration 11 out of 57.
# Iteration 12 out of 57.
# Iteration 13 out of 57.
# Iteration 14 out of 57.
# Iteration 15 out of 57.
# Iteration 16 out of 57.
# Iteration 17 out of 57.
# Iteration 18 out of 57.
# Iteration 19 out of 57.
# Iteration 20 out of 57.
# Iteration 21 out of 57.
# Iteration 22 out of 57.
# Iteration 23 out of 57.
# Iteration 24 out of 57.
# Iteration 25 out of 57.
# Iteration 26 out of 57.
# Iteration 27 out of 57.
# Iteration 28 out of 57.
# Iteration 29 out of 57.
# Iteration 30 out of 57.
# Iteration 31 out of 57.
# Iteration 32 out of 57.
# Iteration 33 out of 57.
# Iteration 34 out of 57.
# Iteration 35 out of 57.
# Iteration 36 out of 57.
# Iteration 37 out of 57.
# Iteration 38 out of 57.
# Iteration 39 out of 57.
# Iteration 40 out of 57.
# Iteration 41 out of 57.
# Iteration 42 out of 57.
# Iteration 43 out of 57.
# Iteration 44 out of 57.
# Iteration 45 out of 57.
# Iteration 46 out of 57.
# Iteration 47 out of 57.
# Iteration 48 out of 57.
# Iteration 49 out of 57.
# Iteration 50 out of 57.
# Iteration 51 out of 57.
# Iteration 52 out of 57.
# Iteration 53 out of 57.
# Iteration 54 out of 57.
# Iteration 55 out of 57.
# Iteration 56 out of 57.
# Iteration 57 out of 57.
# t_eval 3616
# Temperaure Round 75 out of 80.
# Iteration 1 out of 57.
# Iteration 2 out of 57.
# Iteration 3 out of 57.
# Iteration 4 out of 57.
# Iteration 5 out of 57.
# Iteration 6 out of 57.
# Iteration 7 out of 57.
# Iteration 8 out of 57.
# Iteration 9 out of 57.
# Iteration 10 out of 57.
# Iteration 11 out of 57.
# Iteration 12 out of 57.
# Iteration 13 out of 57.
# Iteration 14 out of 57.
# Iteration 15 out of 57.
# Iteration 16 out of 57.
# Iteration 17 out of 57.
# Iteration 18 out of 57.
# Iteration 19 out of 57.
# Iteration 20 out of 57.
# Iteration 21 out of 57.
# Iteration 22 out of 57.
# Iteration 23 out of 57.
# Iteration 24 out of 57.
# Iteration 25 out of 57.
# Iteration 26 out of 57.
# Iteration 27 out of 57.
# Iteration 28 out of 57.
# Iteration 29 out of 57.
# Iteration 30 out of 57.
# Iteration 31 out of 57.
# Iteration 32 out of 57.
# Iteration 33 out of 57.
# Iteration 34 out of 57.
# Iteration 35 out of 57.
# Iteration 36 out of 57.
# Iteration 37 out of 57.
# Iteration 38 out of 57.
# Iteration 39 out of 57.
# Iteration 40 out of 57.
# Iteration 41 out of 57.
# Iteration 42 out of 57.
# Iteration 43 out of 57.
# Iteration 44 out of 57.
# Iteration 45 out of 57.
# Iteration 46 out of 57.
# Iteration 47 out of 57.
# Iteration 48 out of 57.
# Iteration 49 out of 57.
# Iteration 50 out of 57.
# Iteration 51 out of 57.
# Iteration 52 out of 57.
# Iteration 53 out of 57.
# Iteration 54 out of 57.
# Iteration 55 out of 57.
# Iteration 56 out of 57.
# Iteration 57 out of 57.
# t_eval 3673
# Temperaure Round 76 out of 80.
# Iteration 1 out of 58.
# Iteration 2 out of 58.
# Iteration 3 out of 58.
# Iteration 4 out of 58.
# Iteration 5 out of 58.
# Iteration 6 out of 58.
# Iteration 7 out of 58.
# Iteration 8 out of 58.
# Iteration 9 out of 58.
# Iteration 10 out of 58.
# Iteration 11 out of 58.
# Iteration 12 out of 58.
# Iteration 13 out of 58.
# Iteration 14 out of 58.
# Iteration 15 out of 58.
# Iteration 16 out of 58.
# Iteration 17 out of 58.
# Iteration 18 out of 58.
# Iteration 19 out of 58.
# Iteration 20 out of 58.
# Iteration 21 out of 58.
# Iteration 22 out of 58.
# Iteration 23 out of 58.
# Iteration 24 out of 58.
# Iteration 25 out of 58.
# Iteration 26 out of 58.
# Iteration 27 out of 58.
# Iteration 28 out of 58.
# Iteration 29 out of 58.
# Iteration 30 out of 58.
# Iteration 31 out of 58.
# Iteration 32 out of 58.
# Iteration 33 out of 58.
# Iteration 34 out of 58.
# Iteration 35 out of 58.
# Iteration 36 out of 58.
# Iteration 37 out of 58.
# Iteration 38 out of 58.
# Iteration 39 out of 58.
# Iteration 40 out of 58.
# Iteration 41 out of 58.
# Iteration 42 out of 58.
# Iteration 43 out of 58.
# Iteration 44 out of 58.
# Iteration 45 out of 58.
# Iteration 46 out of 58.
# Iteration 47 out of 58.
# Iteration 48 out of 58.
# Iteration 49 out of 58.
# Iteration 50 out of 58.
# Iteration 51 out of 58.
# Iteration 52 out of 58.
# Iteration 53 out of 58.
# Iteration 54 out of 58.
# Iteration 55 out of 58.
# Iteration 56 out of 58.
# Iteration 57 out of 58.
# Iteration 58 out of 58.
# t_eval 3731
# Temperaure Round 77 out of 80.
# Iteration 1 out of 58.
# Iteration 2 out of 58.
# Iteration 3 out of 58.
# Iteration 4 out of 58.
# Iteration 5 out of 58.
# Iteration 6 out of 58.
# Iteration 7 out of 58.
# Iteration 8 out of 58.
# Iteration 9 out of 58.
# Iteration 10 out of 58.
# Iteration 11 out of 58.
# Iteration 12 out of 58.
# Iteration 13 out of 58.
# Iteration 14 out of 58.
# Iteration 15 out of 58.
# Iteration 16 out of 58.
# Iteration 17 out of 58.
# Iteration 18 out of 58.
# Iteration 19 out of 58.
# Iteration 20 out of 58.
# Iteration 21 out of 58.
# Iteration 22 out of 58.
# Iteration 23 out of 58.
# Iteration 24 out of 58.
# Iteration 25 out of 58.
# Iteration 26 out of 58.
# Iteration 27 out of 58.
# Iteration 28 out of 58.
# Iteration 29 out of 58.
# Iteration 30 out of 58.
# Iteration 31 out of 58.
# Iteration 32 out of 58.
# Iteration 33 out of 58.
# Iteration 34 out of 58.
# Iteration 35 out of 58.
# Iteration 36 out of 58.
# Iteration 37 out of 58.
# Iteration 38 out of 58.
# Iteration 39 out of 58.
# Iteration 40 out of 58.
# Iteration 41 out of 58.
# Iteration 42 out of 58.
# Iteration 43 out of 58.
# Iteration 44 out of 58.
# Iteration 45 out of 58.
# Iteration 46 out of 58.
# Iteration 47 out of 58.
# Iteration 48 out of 58.
# Iteration 49 out of 58.
# Iteration 50 out of 58.
# Iteration 51 out of 58.
# Iteration 52 out of 58.
# Iteration 53 out of 58.
# Iteration 54 out of 58.
# Iteration 55 out of 58.
# Iteration 56 out of 58.
# Iteration 57 out of 58.
# Iteration 58 out of 58.
# t_eval 3789
# Temperaure Round 78 out of 80.
# Iteration 1 out of 58.
# Iteration 2 out of 58.
# Iteration 3 out of 58.
# Iteration 4 out of 58.
# Iteration 5 out of 58.
# Iteration 6 out of 58.
# Iteration 7 out of 58.
# Iteration 8 out of 58.
# Iteration 9 out of 58.
# Iteration 10 out of 58.
# Iteration 11 out of 58.
# Iteration 12 out of 58.
# Iteration 13 out of 58.
# Iteration 14 out of 58.
# Iteration 15 out of 58.
# Iteration 16 out of 58.
# Iteration 17 out of 58.
# Iteration 18 out of 58.
# Iteration 19 out of 58.
# Iteration 20 out of 58.
# Iteration 21 out of 58.
# Iteration 22 out of 58.
# Iteration 23 out of 58.
# Iteration 24 out of 58.
# Iteration 25 out of 58.
# Iteration 26 out of 58.
# Iteration 27 out of 58.
# Iteration 28 out of 58.
# Iteration 29 out of 58.
# Iteration 30 out of 58.
# Iteration 31 out of 58.
# Iteration 32 out of 58.
# Iteration 33 out of 58.
# Iteration 34 out of 58.
# Iteration 35 out of 58.
# Iteration 36 out of 58.
# Iteration 37 out of 58.
# Iteration 38 out of 58.
# Iteration 39 out of 58.
# Iteration 40 out of 58.
# Iteration 41 out of 58.
# Iteration 42 out of 58.
# Iteration 43 out of 58.
# Iteration 44 out of 58.
# Iteration 45 out of 58.
# Iteration 46 out of 58.
# Iteration 47 out of 58.
# Iteration 48 out of 58.
# Iteration 49 out of 58.
# Iteration 50 out of 58.
# Iteration 51 out of 58.
# Iteration 52 out of 58.
# Iteration 53 out of 58.
# Iteration 54 out of 58.
# Iteration 55 out of 58.
# Iteration 56 out of 58.
# Iteration 57 out of 58.
# Iteration 58 out of 58.
# t_eval 3847
# Temperaure Round 79 out of 80.
# Iteration 1 out of 59.
# Iteration 2 out of 59.
# Iteration 3 out of 59.
# Iteration 4 out of 59.
# Iteration 5 out of 59.
# Iteration 6 out of 59.
# Iteration 7 out of 59.
# Iteration 8 out of 59.
# Iteration 9 out of 59.
# Iteration 10 out of 59.
# Iteration 11 out of 59.
# Iteration 12 out of 59.
# Iteration 13 out of 59.
# Iteration 14 out of 59.
# Iteration 15 out of 59.
# Iteration 16 out of 59.
# Iteration 17 out of 59.
# Iteration 18 out of 59.
# Iteration 19 out of 59.
# Iteration 20 out of 59.
# Iteration 21 out of 59.
# Iteration 22 out of 59.
# Iteration 23 out of 59.
# Iteration 24 out of 59.
# Iteration 25 out of 59.
# Iteration 26 out of 59.
# Iteration 27 out of 59.
# Iteration 28 out of 59.
# Iteration 29 out of 59.
# Iteration 30 out of 59.
# Iteration 31 out of 59.
# Iteration 32 out of 59.
# Iteration 33 out of 59.
# Iteration 34 out of 59.
# Iteration 35 out of 59.
# Iteration 36 out of 59.
# Iteration 37 out of 59.
# Iteration 38 out of 59.
# Iteration 39 out of 59.
# Iteration 40 out of 59.
# Iteration 41 out of 59.
# Iteration 42 out of 59.
# Iteration 43 out of 59.
# Iteration 44 out of 59.
# Iteration 45 out of 59.
# Iteration 46 out of 59.
# Iteration 47 out of 59.
# Iteration 48 out of 59.
# Iteration 49 out of 59.
# Iteration 50 out of 59.
# Iteration 51 out of 59.
# Iteration 52 out of 59.
# Iteration 53 out of 59.
# Iteration 54 out of 59.
# Iteration 55 out of 59.
# Iteration 56 out of 59.
# Iteration 57 out of 59.
# Iteration 58 out of 59.
# Iteration 59 out of 59.
# t_eval 3906
# Temperaure Round 80 out of 80.
# Iteration 1 out of 94.
# Iteration 2 out of 94.
# Iteration 3 out of 94.
# Iteration 4 out of 94.
# Iteration 5 out of 94.
# Iteration 6 out of 94.
# Iteration 7 out of 94.
# Iteration 8 out of 94.
# Iteration 9 out of 94.
# Iteration 10 out of 94.
# Iteration 11 out of 94.
# Iteration 12 out of 94.
# Iteration 13 out of 94.
# Iteration 14 out of 94.
# Iteration 15 out of 94.
# Iteration 16 out of 94.
# Iteration 17 out of 94.
# Iteration 18 out of 94.
# Iteration 19 out of 94.
# Iteration 20 out of 94.
# Iteration 21 out of 94.
# Iteration 22 out of 94.
# Iteration 23 out of 94.
# Iteration 24 out of 94.
# Iteration 25 out of 94.
# Iteration 26 out of 94.
# Iteration 27 out of 94.
# Iteration 28 out of 94.
# Iteration 29 out of 94.
# Iteration 30 out of 94.
# Iteration 31 out of 94.
# Iteration 32 out of 94.
# Iteration 33 out of 94.
# Iteration 34 out of 94.
# Iteration 35 out of 94.
# Iteration 36 out of 94.
# Iteration 37 out of 94.
# Iteration 38 out of 94.
# Iteration 39 out of 94.
# Iteration 40 out of 94.
# Iteration 41 out of 94.
# Iteration 42 out of 94.
# Iteration 43 out of 94.
# Iteration 44 out of 94.
# Iteration 45 out of 94.
# Iteration 46 out of 94.
# Iteration 47 out of 94.
# Iteration 48 out of 94.
# Iteration 49 out of 94.
# Iteration 50 out of 94.
# Iteration 51 out of 94.
# Iteration 52 out of 94.
# Iteration 53 out of 94.
# Iteration 54 out of 94.
# Iteration 55 out of 94.
# Iteration 56 out of 94.
# Iteration 57 out of 94.
# Iteration 58 out of 94.
# Iteration 59 out of 94.
# Iteration 60 out of 94.
# Iteration 61 out of 94.
# Iteration 62 out of 94.
# Iteration 63 out of 94.
# Iteration 64 out of 94.
# Iteration 65 out of 94.
# Iteration 66 out of 94.
# Iteration 67 out of 94.
# Iteration 68 out of 94.
# Iteration 69 out of 94.
# Iteration 70 out of 94.
# Iteration 71 out of 94.
# Iteration 72 out of 94.
# Iteration 73 out of 94.
# Iteration 74 out of 94.
# Iteration 75 out of 94.
# Iteration 76 out of 94.
# Iteration 77 out of 94.
# Iteration 78 out of 94.
# Iteration 79 out of 94.
# Iteration 80 out of 94.
# Iteration 81 out of 94.
# Iteration 82 out of 94.
# Iteration 83 out of 94.
# Iteration 84 out of 94.
# Iteration 85 out of 94.
# Iteration 86 out of 94.
# Iteration 87 out of 94.
# Iteration 88 out of 94.
# Iteration 89 out of 94.
# Iteration 90 out of 94.
# Iteration 91 out of 94.
# Iteration 92 out of 94.
# Iteration 93 out of 94.
# Iteration 94 out of 94.
# t_eval 4000

# %%
def re_sampling(function, A):
    
    # Used to resample the pareto-optimal front that has been generated by the AMOSA algorithm.
    
    sample_size = 100
    F = []
    
    for i in range(len(A[0])):

        f = np.zeros((sample_size,2))
        
        for j in range(sample_size):
            f[j,:] = list(function(A[0][i],2,seed = rd.randint(1,1000)))

        f_0 = np.mean(f[:,0])
        f_1 = np.mean(f[:,1])

        F.append([f_0,f_1])
        print('Point %d out of %d has been calculated.'%(i + 1,len(A[0])))

    return F

# %%
Resamps = re_sampling(SupplyChain,a)
# Out:
# Point 1 out of 10 has been calculated.
# Point 2 out of 10 has been calculated.
# Point 3 out of 10 has been calculated.
# Point 4 out of 10 has been calculated.
# Point 5 out of 10 has been calculated.
# Point 6 out of 10 has been calculated.
# Point 7 out of 10 has been calculated.
# Point 8 out of 10 has been calculated.
# Point 9 out of 10 has been calculated.
# Point 10 out of 10 has been calculated.

# %% [markdown]
# We now plot our example of the AMOSA code against its resampled counterparts. As we can see, the resampled results are dominated by the AMOSA code, since improvements were made solely based on single evaluations rather than averaged ones.

# %%
R_f1 = []
R_f2 = []

for i in range(len(Resamps)):

    R_f1.append(Resamps[i][0])
    R_f2.append(-Resamps[i][1])
    
X = []
Y = []

for i in range(len(a[1])):
    
    X.append(a[1][i][0])
    Y.append(-a[1][i][1])
 
plt.plot(X,Y,'bx',label = 'AMOSA')
plt.plot(R_f1,R_f2,'rx',label = 'AMOSA Resampled')
plt.legend()
plt.xlabel('Cost')
plt.ylabel('Service')
plt.grid(True)
plt.show()
